# %% [markdown]
# Weather ETL
#
# ![bttf image](bttflogo.png)
#
# Data is being collected to understand what were the weather conditions during a shipment and how those conditions influence the fuel consumption.
#
# In order to showcase my interpretation of the solution the transformation is dissected and showing all the outputs for the specific cell.
#
# In this case the weather data arrives into a landing zone, so in order to reach it let's glob the files:
#
# *Globbing this data takes about 50 secs and the current storage use of the landing zone is 2.26 MB

# %%
import glob
import os
import json
import pandas as pd



# getting the json files names from the landing zone and appending into the data dict
globbed_files = glob.glob(r"C:/Users/E.ALVAREZHERNANDEZ/VS Projects/caseStudy/landing_zone/weather/*.json")

data = [] 
for file in globbed_files:
    frame = pd.read_json(file, lines=True)
    data.append(frame)

data
# Out:
# [        lat       lon      city  \
#  0  47.49835  19.04045  Budapest
#
#                                               weather
#  0  {'dt': 1656637200, 'temp': -11, 'wind': [{'win...  ,
#         lat      lon    city                                            weather
#  0  40.4165 -3.70256  Madrid  {'dt': 1656637200, 'temp': 46, 'wind': [{'wind...,
#      lat       lon   city                                            weather
#  0  53.9  27.56667  Minsk  {'dt': 1656637200, 'temp': 5, 'wind': [{'wind_...,
#          lat       lon    city  \
#  0  55.75222  37.61556  Moscow
#
#                                               weather
#  0  {'dt': 1656637200, 'temp': 45, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  52.22977  21.01178  Warsaw
#
#                                               weather
#  0  {'dt': 1656637200, 'temp': 22, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  39.91987  32.85427  Ankara
#
#                                               weather
#  0  {'dt': 1656640800, 'temp': 48, 'wind': [{'wind...  ,
#          lat      lon       city  \
#  0  41.38879  2.15899  Barcelona
#
#                                               weather
#  0  {'dt': 1656640800, 'temp': -12, 'wind': [{'win...  ,
#          lat      lon  city                                            weather
#  0  50.45466  30.5238  Kyiv  {'dt': 1656640800, 'temp': -16, 'wind': [{'win...,
#         lat      lon    city                                            weather
#  0  40.4165 -3.70256  Madrid  {'dt': 1656640800, 'temp': 5, 'wind': [{'wind_...,
#          lat     lon   city                                            weather
#  0  48.85341  2.3488  Paris  {'dt': 1656640800, 'temp': 12, 'wind': [{'wind...,
#          lat       lon  city                                            weather
#  0  41.89193  12.51133  Rome  {'dt': 1656640800, 'temp': 11, 'wind': [{'wind...,
#          lat       lon       city  \
#  0  59.32938  18.06871  Stockholm
#
#                                               weather
#  0  {'dt': 1656640800, 'temp': -26, 'wind': [{'win...  ,
#          lat       lon    city  \
#  0  48.20849  16.37208  Vienna
#
#                                               weather
#  0  {'dt': 1656640800, 'temp': 42, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  39.91987  32.85427  Ankara
#
#                                               weather
#  0  {'dt': 1656644400, 'temp': 26, 'wind': [{'wind...  ,
#          lat       lon       city  \
#  0  44.43225  26.10626  Bucharest
#
#                                               weather
#  0  {'dt': 1656644400, 'temp': 28, 'wind': [{'wind...  ,
#          lat       lon      city  \
#  0  47.49835  19.04045  Budapest
#
#                                               weather
#  0  {'dt': 1656644400, 'temp': -14, 'wind': [{'win...  ,
#          lat      lon     city  \
#  0  53.55073  9.99302  Hamburg
#
#                                               weather
#  0  {'dt': 1656644400, 'temp': 38, 'wind': [{'wind...  ,
#          lat       lon      city  \
#  0  41.01384  28.94966  Istanbul
#
#                                               weather
#  0  {'dt': 1656644400, 'temp': 43, 'wind': [{'wind...  ,
#          lat      lon  city                                            weather
#  0  50.45466  30.5238  Kyiv  {'dt': 1656644400, 'temp': 18, 'wind': [{'wind...,
#          lat      lon    city  \
#  0  51.50853 -0.12574  London
#
#                                               weather
#  0  {'dt': 1656644400, 'temp': -12, 'wind': [{'win...  ,
#         lat      lon    city                                            weather
#  0  40.4165 -3.70256  Madrid  {'dt': 1656644400, 'temp': 28, 'wind': [{'wind...,
#      lat       lon   city                                            weather
#  0  53.9  27.56667  Minsk  {'dt': 1656644400, 'temp': -24, 'wind': [{'win...,
#          lat       lon  city                                            weather
#  0  41.89193  12.51133  Rome  {'dt': 1656644400, 'temp': 32, 'wind': [{'wind...,
#          lat       lon              city  \
#  0  59.93863  30.31413  Saint Petersburg
#
#                                               weather
#  0  {'dt': 1656644400, 'temp': -19, 'wind': [{'win...  ,
#          lat       lon       city  \
#  0  44.43225  26.10626  Bucharest
#
#                                               weather
#  0  {'dt': 1656648000, 'temp': 43, 'wind': [{'wind...  ,
#          lat       lon      city  \
#  0  41.01384  28.94966  Istanbul
#
#                                               weather
#  0  {'dt': 1656648000, 'temp': 15, 'wind': [{'wind...  ,
#          lat      lon  city                                            weather
#  0  50.45466  30.5238  Kyiv  {'dt': 1656648000, 'temp': -3, 'wind': [{'wind...,
#         lat      lon    city                                            weather
#  0  40.4165 -3.70256  Madrid  {'dt': 1656648000, 'temp': 7, 'wind': [{'wind_...,
#      lat       lon   city                                            weather
#  0  53.9  27.56667  Minsk  {'dt': 1656648000, 'temp': -3, 'wind': [{'wind...,
#          lat     lon   city                                            weather
#  0  48.85341  2.3488  Paris  {'dt': 1656648000, 'temp': 48, 'wind': [{'wind...,
#          lat       lon  city                                            weather
#  0  41.89193  12.51133  Rome  {'dt': 1656648000, 'temp': 1, 'wind': [{'wind_...,
#          lat       lon              city  \
#  0  59.93863  30.31413  Saint Petersburg
#
#                                               weather
#  0  {'dt': 1656648000, 'temp': 2, 'wind': [{'wind_...  ,
#          lat       lon    city  \
#  0  52.22977  21.01178  Warsaw
#
#                                               weather
#  0  {'dt': 1656648000, 'temp': 47, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  39.91987  32.85427  Ankara
#
#                                               weather
#  0  {'dt': 1656651600, 'temp': -26, 'wind': [{'win...  ,
#          lat      lon       city  \
#  0  41.38879  2.15899  Barcelona
#
#                                               weather
#  0  {'dt': 1656651600, 'temp': 42, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  52.52437  13.41053  Berlin
#
#                                               weather
#  0  {'dt': 1656651600, 'temp': 12, 'wind': [{'wind...  ,
#          lat       lon      city  \
#  0  47.49835  19.04045  Budapest
#
#                                               weather
#  0  {'dt': 1656651600, 'temp': 20, 'wind': [{'wind...  ,
#          lat      lon     city  \
#  0  53.55073  9.99302  Hamburg
#
#                                               weather
#  0  {'dt': 1656651600, 'temp': 18, 'wind': [{'wind...  ,
#          lat     lon   city                                            weather
#  0  48.85341  2.3488  Paris  {'dt': 1656651600, 'temp': -25, 'wind': [{'win...,
#          lat       lon              city  \
#  0  59.93863  30.31413  Saint Petersburg
#
#                                               weather
#  0  {'dt': 1656651600, 'temp': 13, 'wind': [{'wind...  ,
#          lat       lon       city  \
#  0  59.32938  18.06871  Stockholm
#
#                                               weather
#  0  {'dt': 1656651600, 'temp': 43, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  48.20849  16.37208  Vienna
#
#                                               weather
#  0  {'dt': 1656651600, 'temp': -27, 'wind': [{'win...  ,
#          lat       lon    city  \
#  0  52.22977  21.01178  Warsaw
#
#                                               weather
#  0  {'dt': 1656651600, 'temp': 41, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  39.91987  32.85427  Ankara
#
#                                               weather
#  0  {'dt': 1656655200, 'temp': 10, 'wind': [{'wind...  ,
#          lat      lon     city  \
#  0  53.55073  9.99302  Hamburg
#
#                                               weather
#  0  {'dt': 1656655200, 'temp': 9, 'wind': [{'wind_...  ,
#          lat      lon    city  \
#  0  51.50853 -0.12574  London
#
#                                               weather
#  0  {'dt': 1656655200, 'temp': 40, 'wind': [{'wind...  ,
#         lat      lon    city                                            weather
#  0  40.4165 -3.70256  Madrid  {'dt': 1656655200, 'temp': -20, 'wind': [{'win...,
#          lat     lon   city                                            weather
#  0  48.85341  2.3488  Paris  {'dt': 1656655200, 'temp': -6, 'wind': [{'wind...,
#          lat       lon  city                                            weather
#  0  41.89193  12.51133  Rome  {'dt': 1656655200, 'temp': 36, 'wind': [{'wind...,
#          lat       lon       city  \
#  0  59.32938  18.06871  Stockholm
#
#                                               weather
#  0  {'dt': 1656655200, 'temp': 30, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  48.20849  16.37208  Vienna
#
#                                               weather
#  0  {'dt': 1656655200, 'temp': 49, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  52.22977  21.01178  Warsaw
#
#                                               weather
#  0  {'dt': 1656655200, 'temp': 27, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  52.52437  13.41053  Berlin
#
#                                               weather
#  0  {'dt': 1656658800, 'temp': 9, 'wind': [{'wind_...  ,
#          lat      lon     city  \
#  0  53.55073  9.99302  Hamburg
#
#                                               weather
#  0  {'dt': 1656658800, 'temp': -29, 'wind': [{'win...  ,
#          lat       lon      city  \
#  0  41.01384  28.94966  Istanbul
#
#                                               weather
#  0  {'dt': 1656658800, 'temp': 30, 'wind': [{'wind...  ,
#          lat      lon    city  \
#  0  51.50853 -0.12574  London
#
#                                               weather
#  0  {'dt': 1656658800, 'temp': 37, 'wind': [{'wind...  ,
#          lat     lon   city                                            weather
#  0  48.85341  2.3488  Paris  {'dt': 1656658800, 'temp': 6, 'wind': [{'wind_...,
#          lat       lon  city                                            weather
#  0  41.89193  12.51133  Rome  {'dt': 1656658800, 'temp': 0, 'wind': [{'wind_...,
#          lat       lon    city  \
#  0  48.20849  16.37208  Vienna
#
#                                               weather
#  0  {'dt': 1656658800, 'temp': -17, 'wind': [{'win...  ,
#          lat       lon    city  \
#  0  52.22977  21.01178  Warsaw
#
#                                               weather
#  0  {'dt': 1656658800, 'temp': 5, 'wind': [{'wind_...  ,
#          lat      lon       city  \
#  0  41.38879  2.15899  Barcelona
#
#                                               weather
#  0  {'dt': 1656662400, 'temp': 26, 'wind': [{'wind...  ,
#          lat       lon      city  \
#  0  47.49835  19.04045  Budapest
#
#                                               weather
#  0  {'dt': 1656662400, 'temp': -9, 'wind': [{'wind...  ,
#          lat       lon      city  \
#  0  41.01384  28.94966  Istanbul
#
#                                               weather
#  0  {'dt': 1656662400, 'temp': 13, 'wind': [{'wind...  ,
#          lat      lon    city  \
#  0  51.50853 -0.12574  London
#
#                                               weather
#  0  {'dt': 1656662400, 'temp': -13, 'wind': [{'win...  ,
#         lat      lon    city                                            weather
#  0  40.4165 -3.70256  Madrid  {'dt': 1656662400, 'temp': 21, 'wind': [{'wind...,
#          lat       lon    city  \
#  0  52.52437  13.41053  Berlin
#
#                                               weather
#  0  {'dt': 1656666000, 'temp': 43, 'wind': [{'wind...  ,
#          lat       lon      city  \
#  0  47.49835  19.04045  Budapest
#
#                                               weather
#  0  {'dt': 1656666000, 'temp': 34, 'wind': [{'wind...  ,
#          lat      lon    city  \
#  0  51.50853 -0.12574  London
#
#                                               weather
#  0  {'dt': 1656666000, 'temp': 25, 'wind': [{'wind...  ,
#         lat      lon    city                                            weather
#  0  40.4165 -3.70256  Madrid  {'dt': 1656666000, 'temp': 24, 'wind': [{'wind...,
#      lat       lon   city                                            weather
#  0  53.9  27.56667  Minsk  {'dt': 1656666000, 'temp': -25, 'wind': [{'win...,
#          lat     lon   city                                            weather
#  0  48.85341  2.3488  Paris  {'dt': 1656666000, 'temp': 21, 'wind': [{'wind...,
#          lat       lon  city                                            weather
#  0  41.89193  12.51133  Rome  {'dt': 1656666000, 'temp': -4, 'wind': [{'wind...,
#          lat       lon              city  \
#  0  59.93863  30.31413  Saint Petersburg
#
#                                               weather
#  0  {'dt': 1656666000, 'temp': 16, 'wind': [{'wind...  ,
#          lat       lon       city  \
#  0  59.32938  18.06871  Stockholm
#
#                                               weather
#  0  {'dt': 1656666000, 'temp': -10, 'wind': [{'win...  ,
#          lat       lon    city  \
#  0  39.91987  32.85427  Ankara
#
#                                               weather
#  0  {'dt': 1656669600, 'temp': -18, 'wind': [{'win...  ,
#          lat      lon       city  \
#  0  41.38879  2.15899  Barcelona
#
#                                               weather
#  0  {'dt': 1656669600, 'temp': -4, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  52.52437  13.41053  Berlin
#
#                                               weather
#  0  {'dt': 1656669600, 'temp': 3, 'wind': [{'wind_...  ,
#          lat       lon       city  \
#  0  44.43225  26.10626  Bucharest
#
#                                               weather
#  0  {'dt': 1656669600, 'temp': -8, 'wind': [{'wind...  ,
#          lat       lon      city  \
#  0  47.49835  19.04045  Budapest
#
#                                               weather
#  0  {'dt': 1656669600, 'temp': -14, 'wind': [{'win...  ,
#      lat       lon   city                                            weather
#  0  53.9  27.56667  Minsk  {'dt': 1656669600, 'temp': 15, 'wind': [{'wind...,
#          lat     lon   city                                            weather
#  0  48.85341  2.3488  Paris  {'dt': 1656669600, 'temp': 34, 'wind': [{'wind...,
#          lat       lon  city                                            weather
#  0  41.89193  12.51133  Rome  {'dt': 1656669600, 'temp': 19, 'wind': [{'wind...,
#          lat       lon              city  \
#  0  59.93863  30.31413  Saint Petersburg
#
#                                               weather
#  0  {'dt': 1656669600, 'temp': -12, 'wind': [{'win...  ,
#          lat       lon       city  \
#  0  59.32938  18.06871  Stockholm
#
#                                               weather
#  0  {'dt': 1656669600, 'temp': 10, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  52.52437  13.41053  Berlin
#
#                                               weather
#  0  {'dt': 1656673200, 'temp': 4, 'wind': [{'wind_...  ,
#          lat       lon       city  \
#  0  44.43225  26.10626  Bucharest
#
#                                               weather
#  0  {'dt': 1656673200, 'temp': 45, 'wind': [{'wind...  ,
#          lat       lon      city  \
#  0  41.01384  28.94966  Istanbul
#
#                                               weather
#  0  {'dt': 1656673200, 'temp': -23, 'wind': [{'win...  ,
#          lat      lon    city  \
#  0  51.50853 -0.12574  London
#
#                                               weather
#  0  {'dt': 1656673200, 'temp': -9, 'wind': [{'wind...  ,
#          lat     lon   city                                            weather
#  0  48.85341  2.3488  Paris  {'dt': 1656673200, 'temp': 28, 'wind': [{'wind...,
#          lat       lon  city                                            weather
#  0  41.89193  12.51133  Rome  {'dt': 1656673200, 'temp': 6, 'wind': [{'wind_...,
#          lat       lon    city  \
#  0  48.20849  16.37208  Vienna
#
#                                               weather
#  0  {'dt': 1656673200, 'temp': 24, 'wind': [{'wind...  ,
#          lat      lon       city  \
#  0  41.38879  2.15899  Barcelona
#
#                                               weather
#  0  {'dt': 1656676800, 'temp': 32, 'wind': [{'wind...  ,
#          lat       lon       city  \
#  0  44.43225  26.10626  Bucharest
#
#                                               weather
#  0  {'dt': 1656676800, 'temp': 7, 'wind': [{'wind_...  ,
#          lat       lon      city  \
#  0  47.49835  19.04045  Budapest
#
#                                               weather
#  0  {'dt': 1656676800, 'temp': 8, 'wind': [{'wind_...  ,
#          lat      lon    city  \
#  0  51.50853 -0.12574  London
#
#                                               weather
#  0  {'dt': 1656676800, 'temp': -29, 'wind': [{'win...  ,
#         lat      lon    city                                            weather
#  0  40.4165 -3.70256  Madrid  {'dt': 1656676800, 'temp': 16, 'wind': [{'wind...,
#          lat       lon    city  \
#  0  55.75222  37.61556  Moscow
#
#                                               weather
#  0  {'dt': 1656676800, 'temp': -24, 'wind': [{'win...  ,
#          lat       lon  city                                            weather
#  0  41.89193  12.51133  Rome  {'dt': 1656676800, 'temp': 26, 'wind': [{'wind...,
#          lat       lon              city  \
#  0  59.93863  30.31413  Saint Petersburg
#
#                                               weather
#  0  {'dt': 1656676800, 'temp': 30, 'wind': [{'wind...  ,
#          lat       lon       city  \
#  0  59.32938  18.06871  Stockholm
#
#                                               weather
#  0  {'dt': 1656676800, 'temp': 9, 'wind': [{'wind_...  ,
#          lat       lon    city  \
#  0  48.20849  16.37208  Vienna
#
#                                               weather
#  0  {'dt': 1656676800, 'temp': 45, 'wind': [{'wind...  ,
#          lat      lon       city  \
#  0  41.38879  2.15899  Barcelona
#
#                                               weather
#  0  {'dt': 1656680400, 'temp': 11, 'wind': [{'wind...  ,
#          lat       lon       city  \
#  0  44.43225  26.10626  Bucharest
#
#                                               weather
#  0  {'dt': 1656680400, 'temp': -20, 'wind': [{'win...  ,
#          lat       lon      city  \
#  0  47.49835  19.04045  Budapest
#
#                                               weather
#  0  {'dt': 1656680400, 'temp': 23, 'wind': [{'wind...  ,
#          lat      lon  city                                            weather
#  0  50.45466  30.5238  Kyiv  {'dt': 1656680400, 'temp': 34, 'wind': [{'wind...,
#         lat      lon    city                                            weather
#  0  40.4165 -3.70256  Madrid  {'dt': 1656680400, 'temp': -6, 'wind': [{'wind...,
#          lat     lon   city                                            weather
#  0  48.85341  2.3488  Paris  {'dt': 1656680400, 'temp': 14, 'wind': [{'wind...,
#          lat       lon       city  \
#  0  59.32938  18.06871  Stockholm
#
#                                               weather
#  0  {'dt': 1656680400, 'temp': 15, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  48.20849  16.37208  Vienna
#
#                                               weather
#  0  {'dt': 1656680400, 'temp': 11, 'wind': [{'wind...  ,
#          lat       lon       city  \
#  0  44.43225  26.10626  Bucharest
#
#                                               weather
#  0  {'dt': 1656684000, 'temp': 37, 'wind': [{'wind...  ,
#          lat      lon     city  \
#  0  53.55073  9.99302  Hamburg
#
#                                               weather
#  0  {'dt': 1656684000, 'temp': 16, 'wind': [{'wind...  ,
#          lat      lon  city                                            weather
#  0  50.45466  30.5238  Kyiv  {'dt': 1656684000, 'temp': -12, 'wind': [{'win...,
#          lat       lon    city  \
#  0  55.75222  37.61556  Moscow
#
#                                               weather
#  0  {'dt': 1656684000, 'temp': 30, 'wind': [{'wind...  ,
#          lat     lon   city                                            weather
#  0  48.85341  2.3488  Paris  {'dt': 1656684000, 'temp': 21, 'wind': [{'wind...,
#          lat       lon       city  \
#  0  59.32938  18.06871  Stockholm
#
#                                               weather
#  0  {'dt': 1656684000, 'temp': -21, 'wind': [{'win...  ,
#          lat       lon    city  \
#  0  48.20849  16.37208  Vienna
#
#                                               weather
#  0  {'dt': 1656684000, 'temp': 30, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  52.22977  21.01178  Warsaw
#
#                                               weather
#  0  {'dt': 1656684000, 'temp': 43, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  39.91987  32.85427  Ankara
#
#                                               weather
#  0  {'dt': 1656687600, 'temp': 36, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  52.52437  13.41053  Berlin
#
#                                               weather
#  0  {'dt': 1656687600, 'temp': 23, 'wind': [{'wind...  ,
#          lat      lon     city  \
#  0  53.55073  9.99302  Hamburg
#
#                                               weather
#  0  {'dt': 1656687600, 'temp': 21, 'wind': [{'wind...  ,
#          lat      lon    city  \
#  0  51.50853 -0.12574  London
#
#                                               weather
#  0  {'dt': 1656687600, 'temp': 27, 'wind': [{'wind...  ,
#         lat      lon    city                                            weather
#  0  40.4165 -3.70256  Madrid  {'dt': 1656687600, 'temp': 29, 'wind': [{'wind...,
#      lat       lon   city                                            weather
#  0  53.9  27.56667  Minsk  {'dt': 1656687600, 'temp': 3, 'wind': [{'wind_...,
#          lat       lon    city  \
#  0  55.75222  37.61556  Moscow
#
#                                               weather
#  0  {'dt': 1656687600, 'temp': 4, 'wind': [{'wind_...  ,
#          lat       lon  city                                            weather
#  0  41.89193  12.51133  Rome  {'dt': 1656687600, 'temp': -5, 'wind': [{'wind...,
#          lat       lon              city  \
#  0  59.93863  30.31413  Saint Petersburg
#
#                                               weather
#  0  {'dt': 1656687600, 'temp': -15, 'wind': [{'win...  ,
#          lat       lon    city  \
#  0  48.20849  16.37208  Vienna
#
#                                               weather
#  0  {'dt': 1656687600, 'temp': 49, 'wind': [{'wind...  ,
#          lat      lon       city  \
#  0  41.38879  2.15899  Barcelona
#
#                                               weather
#  0  {'dt': 1656691200, 'temp': 17, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  52.52437  13.41053  Berlin
#
#                                               weather
#  0  {'dt': 1656691200, 'temp': 10, 'wind': [{'wind...  ,
#          lat       lon      city  \
#  0  47.49835  19.04045  Budapest
#
#                                               weather
#  0  {'dt': 1656691200, 'temp': 46, 'wind': [{'wind...  ,
#          lat      lon     city  \
#  0  53.55073  9.99302  Hamburg
#
#                                               weather
#  0  {'dt': 1656691200, 'temp': -17, 'wind': [{'win...  ,
#          lat      lon  city                                            weather
#  0  50.45466  30.5238  Kyiv  {'dt': 1656691200, 'temp': -4, 'wind': [{'wind...,
#          lat      lon    city  \
#  0  51.50853 -0.12574  London
#
#                                               weather
#  0  {'dt': 1656691200, 'temp': -22, 'wind': [{'win...  ,
#          lat       lon    city  \
#  0  55.75222  37.61556  Moscow
#
#                                               weather
#  0  {'dt': 1656691200, 'temp': 29, 'wind': [{'wind...  ,
#          lat     lon   city                                            weather
#  0  48.85341  2.3488  Paris  {'dt': 1656691200, 'temp': -8, 'wind': [{'wind...,
#          lat       lon  city                                            weather
#  0  41.89193  12.51133  Rome  {'dt': 1656691200, 'temp': -10, 'wind': [{'win...,
#          lat       lon              city  \
#  0  59.93863  30.31413  Saint Petersburg
#
#                                               weather
#  0  {'dt': 1656691200, 'temp': 15, 'wind': [{'wind...  ,
#          lat       lon       city  \
#  0  59.32938  18.06871  Stockholm
#
#                                               weather
#  0  {'dt': 1656691200, 'temp': -4, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  48.20849  16.37208  Vienna
#
#                                               weather
#  0  {'dt': 1656691200, 'temp': 11, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  52.22977  21.01178  Warsaw
#
#                                               weather
#  0  {'dt': 1656691200, 'temp': 42, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  39.91987  32.85427  Ankara
#
#                                               weather
#  0  {'dt': 1656694800, 'temp': 30, 'wind': [{'wind...  ,
#          lat      lon       city  \
#  0  41.38879  2.15899  Barcelona
#
#                                               weather
#  0  {'dt': 1656694800, 'temp': 30, 'wind': [{'wind...  ,
#          lat      lon     city  \
#  0  53.55073  9.99302  Hamburg
#
#                                               weather
#  0  {'dt': 1656694800, 'temp': 25, 'wind': [{'wind...  ,
#          lat       lon      city  \
#  0  41.01384  28.94966  Istanbul
#
#                                               weather
#  0  {'dt': 1656694800, 'temp': -15, 'wind': [{'win...  ,
#          lat      lon    city  \
#  0  51.50853 -0.12574  London
#
#                                               weather
#  0  {'dt': 1656694800, 'temp': -11, 'wind': [{'win...  ,
#         lat      lon    city                                            weather
#  0  40.4165 -3.70256  Madrid  {'dt': 1656694800, 'temp': 47, 'wind': [{'wind...,
#          lat       lon    city  \
#  0  55.75222  37.61556  Moscow
#
#                                               weather
#  0  {'dt': 1656694800, 'temp': 6, 'wind': [{'wind_...  ,
#          lat     lon   city                                            weather
#  0  48.85341  2.3488  Paris  {'dt': 1656694800, 'temp': 2, 'wind': [{'wind_...,
#          lat       lon  city                                            weather
#  0  41.89193  12.51133  Rome  {'dt': 1656694800, 'temp': 15, 'wind': [{'wind...,
#          lat       lon              city  \
#  0  59.93863  30.31413  Saint Petersburg
#
#                                               weather
#  0  {'dt': 1656694800, 'temp': 50, 'wind': [{'wind...  ,
#          lat       lon       city  \
#  0  59.32938  18.06871  Stockholm
#
#                                               weather
#  0  {'dt': 1656694800, 'temp': 31, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  48.20849  16.37208  Vienna
#
#                                               weather
#  0  {'dt': 1656694800, 'temp': 47, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  39.91987  32.85427  Ankara
#
#                                               weather
#  0  {'dt': 1656698400, 'temp': 12, 'wind': [{'wind...  ,
#          lat      lon       city  \
#  0  41.38879  2.15899  Barcelona
#
#                                               weather
#  0  {'dt': 1656698400, 'temp': 41, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  52.52437  13.41053  Berlin
#
#                                               weather
#  0  {'dt': 1656698400, 'temp': 42, 'wind': [{'wind...  ,
#          lat       lon       city  \
#  0  44.43225  26.10626  Bucharest
#
#                                               weather
#  0  {'dt': 1656698400, 'temp': 2, 'wind': [{'wind_...  ,
#          lat      lon     city  \
#  0  53.55073  9.99302  Hamburg
#
#                                               weather
#  0  {'dt': 1656698400, 'temp': 7, 'wind': [{'wind_...  ,
#          lat      lon  city                                            weather
#  0  50.45466  30.5238  Kyiv  {'dt': 1656698400, 'temp': 37, 'wind': [{'wind...,
#         lat      lon    city                                            weather
#  0  40.4165 -3.70256  Madrid  {'dt': 1656698400, 'temp': -26, 'wind': [{'win...,
#          lat     lon   city                                            weather
#  0  48.85341  2.3488  Paris  {'dt': 1656698400, 'temp': 4, 'wind': [{'wind_...,
#          lat       lon  city                                            weather
#  0  41.89193  12.51133  Rome  {'dt': 1656698400, 'temp': -30, 'wind': [{'win...,
#          lat       lon              city  \
#  0  59.93863  30.31413  Saint Petersburg
#
#                                               weather
#  0  {'dt': 1656698400, 'temp': 3, 'wind': [{'wind_...  ,
#          lat       lon       city  \
#  0  59.32938  18.06871  Stockholm
#
#                                               weather
#  0  {'dt': 1656698400, 'temp': -23, 'wind': [{'win...  ,
#          lat       lon    city  \
#  0  52.22977  21.01178  Warsaw
#
#                                               weather
#  0  {'dt': 1656698400, 'temp': 50, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  39.91987  32.85427  Ankara
#
#                                               weather
#  0  {'dt': 1656702000, 'temp': 9, 'wind': [{'wind_...  ,
#          lat      lon       city  \
#  0  41.38879  2.15899  Barcelona
#
#                                               weather
#  0  {'dt': 1656702000, 'temp': -9, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  52.52437  13.41053  Berlin
#
#                                               weather
#  0  {'dt': 1656702000, 'temp': 5, 'wind': [{'wind_...  ,
#          lat       lon      city  \
#  0  47.49835  19.04045  Budapest
#
#                                               weather
#  0  {'dt': 1656702000, 'temp': 33, 'wind': [{'wind...  ,
#          lat      lon     city  \
#  0  53.55073  9.99302  Hamburg
#
#                                               weather
#  0  {'dt': 1656702000, 'temp': -12, 'wind': [{'win...  ,
#          lat      lon  city                                            weather
#  0  50.45466  30.5238  Kyiv  {'dt': 1656702000, 'temp': -16, 'wind': [{'win...,
#          lat      lon    city  \
#  0  51.50853 -0.12574  London
#
#                                               weather
#  0  {'dt': 1656702000, 'temp': 23, 'wind': [{'wind...  ,
#      lat       lon   city                                            weather
#  0  53.9  27.56667  Minsk  {'dt': 1656702000, 'temp': 33, 'wind': [{'wind...,
#          lat       lon              city  \
#  0  59.93863  30.31413  Saint Petersburg
#
#                                               weather
#  0  {'dt': 1656702000, 'temp': 39, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  52.22977  21.01178  Warsaw
#
#                                               weather
#  0  {'dt': 1656702000, 'temp': 20, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  39.91987  32.85427  Ankara
#
#                                               weather
#  0  {'dt': 1656705600, 'temp': 36, 'wind': [{'wind...  ,
#          lat      lon       city  \
#  0  41.38879  2.15899  Barcelona
#
#                                               weather
#  0  {'dt': 1656705600, 'temp': 15, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  52.52437  13.41053  Berlin
#
#                                               weather
#  0  {'dt': 1656705600, 'temp': 22, 'wind': [{'wind...  ,
#          lat       lon      city  \
#  0  47.49835  19.04045  Budapest
#
#                                               weather
#  0  {'dt': 1656705600, 'temp': 30, 'wind': [{'wind...  ,
#          lat      lon     city  \
#  0  53.55073  9.99302  Hamburg
#
#                                               weather
#  0  {'dt': 1656705600, 'temp': 39, 'wind': [{'wind...  ,
#          lat       lon      city  \
#  0  41.01384  28.94966  Istanbul
#
#                                               weather
#  0  {'dt': 1656705600, 'temp': 41, 'wind': [{'wind...  ,
#      lat       lon   city                                            weather
#  0  53.9  27.56667  Minsk  {'dt': 1656705600, 'temp': 42, 'wind': [{'wind...,
#          lat       lon    city  \
#  0  55.75222  37.61556  Moscow
#
#                                               weather
#  0  {'dt': 1656705600, 'temp': 48, 'wind': [{'wind...  ,
#          lat     lon   city                                            weather
#  0  48.85341  2.3488  Paris  {'dt': 1656705600, 'temp': 30, 'wind': [{'wind...,
#          lat       lon       city  \
#  0  59.32938  18.06871  Stockholm
#
#                                               weather
#  0  {'dt': 1656705600, 'temp': 47, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  48.20849  16.37208  Vienna
#
#                                               weather
#  0  {'dt': 1656705600, 'temp': 21, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  39.91987  32.85427  Ankara
#
#                                               weather
#  0  {'dt': 1656709200, 'temp': -16, 'wind': [{'win...  ,
#          lat      lon       city  \
#  0  41.38879  2.15899  Barcelona
#
#                                               weather
#  0  {'dt': 1656709200, 'temp': 37, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  52.52437  13.41053  Berlin
#
#                                               weather
#  0  {'dt': 1656709200, 'temp': -2, 'wind': [{'wind...  ,
#          lat       lon       city  \
#  0  44.43225  26.10626  Bucharest
#
#                                               weather
#  0  {'dt': 1656709200, 'temp': 45, 'wind': [{'wind...  ,
#          lat       lon      city  \
#  0  47.49835  19.04045  Budapest
#
#                                               weather
#  0  {'dt': 1656709200, 'temp': 31, 'wind': [{'wind...  ,
#          lat      lon  city                                            weather
#  0  50.45466  30.5238  Kyiv  {'dt': 1656709200, 'temp': 9, 'wind': [{'wind_...,
#         lat      lon    city                                            weather
#  0  40.4165 -3.70256  Madrid  {'dt': 1656709200, 'temp': 4, 'wind': [{'wind_...,
#      lat       lon   city                                            weather
#  0  53.9  27.56667  Minsk  {'dt': 1656709200, 'temp': 18, 'wind': [{'wind...,
#          lat     lon   city                                            weather
#  0  48.85341  2.3488  Paris  {'dt': 1656709200, 'temp': 33, 'wind': [{'wind...,
#          lat       lon  city                                            weather
#  0  41.89193  12.51133  Rome  {'dt': 1656709200, 'temp': 33, 'wind': [{'wind...,
#          lat       lon              city  \
#  0  59.93863  30.31413  Saint Petersburg
#
#                                               weather
#  0  {'dt': 1656709200, 'temp': 28, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  48.20849  16.37208  Vienna
#
#                                               weather
#  0  {'dt': 1656709200, 'temp': 15, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  39.91987  32.85427  Ankara
#
#                                               weather
#  0  {'dt': 1656712800, 'temp': -13, 'wind': [{'win...  ,
#          lat      lon       city  \
#  0  41.38879  2.15899  Barcelona
#
#                                               weather
#  0  {'dt': 1656712800, 'temp': 14, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  52.52437  13.41053  Berlin
#
#                                               weather
#  0  {'dt': 1656712800, 'temp': 34, 'wind': [{'wind...  ,
#          lat       lon       city  \
#  0  44.43225  26.10626  Bucharest
#
#                                               weather
#  0  {'dt': 1656712800, 'temp': -9, 'wind': [{'wind...  ,
#          lat       lon      city  \
#  0  47.49835  19.04045  Budapest
#
#                                               weather
#  0  {'dt': 1656712800, 'temp': -28, 'wind': [{'win...  ,
#          lat      lon     city  \
#  0  53.55073  9.99302  Hamburg
#
#                                               weather
#  0  {'dt': 1656712800, 'temp': 6, 'wind': [{'wind_...  ,
#          lat      lon    city  \
#  0  51.50853 -0.12574  London
#
#                                               weather
#  0  {'dt': 1656712800, 'temp': 34, 'wind': [{'wind...  ,
#      lat       lon   city                                            weather
#  0  53.9  27.56667  Minsk  {'dt': 1656712800, 'temp': 4, 'wind': [{'wind_...,
#          lat       lon    city  \
#  0  55.75222  37.61556  Moscow
#
#                                               weather
#  0  {'dt': 1656712800, 'temp': -24, 'wind': [{'win...  ,
#          lat       lon  city                                            weather
#  0  41.89193  12.51133  Rome  {'dt': 1656712800, 'temp': 2, 'wind': [{'wind_...,
#          lat       lon    city  \
#  0  48.20849  16.37208  Vienna
#
#                                               weather
#  0  {'dt': 1656712800, 'temp': 35, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  39.91987  32.85427  Ankara
#
#                                               weather
#  0  {'dt': 1656716400, 'temp': 21, 'wind': [{'wind...  ,
#          lat      lon       city  \
#  0  41.38879  2.15899  Barcelona
#
#                                               weather
#  0  {'dt': 1656716400, 'temp': -15, 'wind': [{'win...  ,
#          lat       lon    city  \
#  0  52.52437  13.41053  Berlin
#
#                                               weather
#  0  {'dt': 1656716400, 'temp': -23, 'wind': [{'win...  ,
#          lat       lon      city  \
#  0  47.49835  19.04045  Budapest
#
#                                               weather
#  0  {'dt': 1656716400, 'temp': 23, 'wind': [{'wind...  ,
#          lat      lon     city  \
#  0  53.55073  9.99302  Hamburg
#
#                                               weather
#  0  {'dt': 1656716400, 'temp': 22, 'wind': [{'wind...  ,
#          lat       lon      city  \
#  0  41.01384  28.94966  Istanbul
#
#                                               weather
#  0  {'dt': 1656716400, 'temp': 5, 'wind': [{'wind_...  ,
#          lat      lon  city                                            weather
#  0  50.45466  30.5238  Kyiv  {'dt': 1656716400, 'temp': -21, 'wind': [{'win...,
#          lat      lon    city  \
#  0  51.50853 -0.12574  London
#
#                                               weather
#  0  {'dt': 1656716400, 'temp': 37, 'wind': [{'wind...  ,
#      lat       lon   city                                            weather
#  0  53.9  27.56667  Minsk  {'dt': 1656716400, 'temp': 39, 'wind': [{'wind...,
#          lat       lon  city                                            weather
#  0  41.89193  12.51133  Rome  {'dt': 1656716400, 'temp': -19, 'wind': [{'win...,
#          lat       lon              city  \
#  0  59.93863  30.31413  Saint Petersburg
#
#                                               weather
#  0  {'dt': 1656716400, 'temp': 22, 'wind': [{'wind...  ,
#          lat       lon       city  \
#  0  59.32938  18.06871  Stockholm
#
#                                               weather
#  0  {'dt': 1656716400, 'temp': 24, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  48.20849  16.37208  Vienna
#
#                                               weather
#  0  {'dt': 1656716400, 'temp': 21, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  39.91987  32.85427  Ankara
#
#                                               weather
#  0  {'dt': 1656720000, 'temp': 45, 'wind': [{'wind...  ,
#          lat      lon       city  \
#  0  41.38879  2.15899  Barcelona
#
#                                               weather
#  0  {'dt': 1656720000, 'temp': 50, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  52.52437  13.41053  Berlin
#
#                                               weather
#  0  {'dt': 1656720000, 'temp': 41, 'wind': [{'wind...  ,
#          lat       lon      city  \
#  0  47.49835  19.04045  Budapest
#
#                                               weather
#  0  {'dt': 1656720000, 'temp': 14, 'wind': [{'wind...  ,
#          lat      lon     city  \
#  0  53.55073  9.99302  Hamburg
#
#                                               weather
#  0  {'dt': 1656720000, 'temp': -5, 'wind': [{'wind...  ,
#          lat       lon      city  \
#  0  41.01384  28.94966  Istanbul
#
#                                               weather
#  0  {'dt': 1656720000, 'temp': 24, 'wind': [{'wind...  ,
#          lat      lon  city                                            weather
#  0  50.45466  30.5238  Kyiv  {'dt': 1656720000, 'temp': 13, 'wind': [{'wind...,
#          lat      lon    city  \
#  0  51.50853 -0.12574  London
#
#                                               weather
#  0  {'dt': 1656720000, 'temp': 26, 'wind': [{'wind...  ,
#      lat       lon   city                                            weather
#  0  53.9  27.56667  Minsk  {'dt': 1656720000, 'temp': 18, 'wind': [{'wind...,
#          lat       lon    city  \
#  0  55.75222  37.61556  Moscow
#
#                                               weather
#  0  {'dt': 1656720000, 'temp': 15, 'wind': [{'wind...  ,
#          lat     lon   city                                            weather
#  0  48.85341  2.3488  Paris  {'dt': 1656720000, 'temp': 30, 'wind': [{'wind...,
#          lat       lon              city  \
#  0  59.93863  30.31413  Saint Petersburg
#
#                                               weather
#  0  {'dt': 1656720000, 'temp': -2, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  48.20849  16.37208  Vienna
#
#                                               weather
#  0  {'dt': 1656720000, 'temp': 46, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  39.91987  32.85427  Ankara
#
#                                               weather
#  0  {'dt': 1656723600, 'temp': 0, 'wind': [{'wind_...  ,
#          lat      lon       city  \
#  0  41.38879  2.15899  Barcelona
#
#                                               weather
#  0  {'dt': 1656723600, 'temp': 21, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  52.52437  13.41053  Berlin
#
#                                               weather
#  0  {'dt': 1656723600, 'temp': 17, 'wind': [{'wind...  ,
#          lat       lon      city  \
#  0  47.49835  19.04045  Budapest
#
#                                               weather
#  0  {'dt': 1656723600, 'temp': 33, 'wind': [{'wind...  ,
#          lat      lon     city  \
#  0  53.55073  9.99302  Hamburg
#
#                                               weather
#  0  {'dt': 1656723600, 'temp': -25, 'wind': [{'win...  ,
#          lat       lon      city  \
#  0  41.01384  28.94966  Istanbul
#
#                                               weather
#  0  {'dt': 1656723600, 'temp': 40, 'wind': [{'wind...  ,
#          lat      lon  city                                            weather
#  0  50.45466  30.5238  Kyiv  {'dt': 1656723600, 'temp': 8, 'wind': [{'wind_...,
#         lat      lon    city                                            weather
#  0  40.4165 -3.70256  Madrid  {'dt': 1656723600, 'temp': 12, 'wind': [{'wind...,
#      lat       lon   city                                            weather
#  0  53.9  27.56667  Minsk  {'dt': 1656723600, 'temp': 15, 'wind': [{'wind...,
#          lat       lon    city  \
#  0  55.75222  37.61556  Moscow
#
#                                               weather
#  0  {'dt': 1656723600, 'temp': 36, 'wind': [{'wind...  ,
#          lat       lon  city                                            weather
#  0  41.89193  12.51133  Rome  {'dt': 1656723600, 'temp': 14, 'wind': [{'wind...,
#          lat       lon              city  \
#  0  59.93863  30.31413  Saint Petersburg
#
#                                               weather
#  0  {'dt': 1656723600, 'temp': -10, 'wind': [{'win...  ,
#          lat       lon       city  \
#  0  59.32938  18.06871  Stockholm
#
#                                               weather
#  0  {'dt': 1656723600, 'temp': 31, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  48.20849  16.37208  Vienna
#
#                                               weather
#  0  {'dt': 1656723600, 'temp': 19, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  52.22977  21.01178  Warsaw
#
#                                               weather
#  0  {'dt': 1656723600, 'temp': 6, 'wind': [{'wind_...  ,
#          lat       lon    city  \
#  0  39.91987  32.85427  Ankara
#
#                                               weather
#  0  {'dt': 1656727200, 'temp': -16, 'wind': [{'win...  ,
#          lat      lon       city  \
#  0  41.38879  2.15899  Barcelona
#
#                                               weather
#  0  {'dt': 1656727200, 'temp': -6, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  52.52437  13.41053  Berlin
#
#                                               weather
#  0  {'dt': 1656727200, 'temp': 19, 'wind': [{'wind...  ,
#          lat       lon      city  \
#  0  47.49835  19.04045  Budapest
#
#                                               weather
#  0  {'dt': 1656727200, 'temp': 2, 'wind': [{'wind_...  ,
#          lat      lon     city  \
#  0  53.55073  9.99302  Hamburg
#
#                                               weather
#  0  {'dt': 1656727200, 'temp': 46, 'wind': [{'wind...  ,
#          lat       lon      city  \
#  0  41.01384  28.94966  Istanbul
#
#                                               weather
#  0  {'dt': 1656727200, 'temp': -17, 'wind': [{'win...  ,
#          lat      lon    city  \
#  0  51.50853 -0.12574  London
#
#                                               weather
#  0  {'dt': 1656727200, 'temp': -18, 'wind': [{'win...  ,
#         lat      lon    city                                            weather
#  0  40.4165 -3.70256  Madrid  {'dt': 1656727200, 'temp': 48, 'wind': [{'wind...,
#      lat       lon   city                                            weather
#  0  53.9  27.56667  Minsk  {'dt': 1656727200, 'temp': -4, 'wind': [{'wind...,
#          lat       lon    city  \
#  0  55.75222  37.61556  Moscow
#
#                                               weather
#  0  {'dt': 1656727200, 'temp': 35, 'wind': [{'wind...  ,
#          lat     lon   city                                            weather
#  0  48.85341  2.3488  Paris  {'dt': 1656727200, 'temp': -13, 'wind': [{'win...,
#          lat       lon  city                                            weather
#  0  41.89193  12.51133  Rome  {'dt': 1656727200, 'temp': -15, 'wind': [{'win...,
#          lat       lon              city  \
#  0  59.93863  30.31413  Saint Petersburg
#
#                                               weather
#  0  {'dt': 1656727200, 'temp': 48, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  48.20849  16.37208  Vienna
#
#                                               weather
#  0  {'dt': 1656727200, 'temp': 33, 'wind': [{'wind...  ,
#          lat      lon       city  \
#  0  41.38879  2.15899  Barcelona
#
#                                               weather
#  0  {'dt': 1656730800, 'temp': 15, 'wind': [{'wind...  ,
#          lat       lon      city  \
#  0  47.49835  19.04045  Budapest
#
#                                               weather
#  0  {'dt': 1656730800, 'temp': 4, 'wind': [{'wind_...  ,
#          lat      lon     city  \
#  0  53.55073  9.99302  Hamburg
#
#                                               weather
#  0  {'dt': 1656730800, 'temp': -14, 'wind': [{'win...  ,
#          lat       lon      city  \
#  0  41.01384  28.94966  Istanbul
#
#                                               weather
#  0  {'dt': 1656730800, 'temp': 12, 'wind': [{'wind...  ,
#          lat      lon  city                                            weather
#  0  50.45466  30.5238  Kyiv  {'dt': 1656730800, 'temp': -18, 'wind': [{'win...,
#          lat      lon    city  \
#  0  51.50853 -0.12574  London
#
#                                               weather
# ...
#  0  {'dt': 1656900000, 'temp': -7, 'wind': [{'wind...  ,
#          lat       lon       city  \
#  0  59.32938  18.06871  Stockholm
#
#                                               weather
#  0  {'dt': 1656900000, 'temp': 22, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  52.22977  21.01178  Warsaw
#
#                                               weather
#  0  {'dt': 1656900000, 'temp': 18, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  39.91987  32.85427  Ankara
#
#                                               weather
#  0  {'dt': 1656903600, 'temp': 16, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  52.52437  13.41053  Berlin
#
#                                               weather
#  0  {'dt': 1656903600, 'temp': 22, 'wind': [{'wind...  ,
#          lat       lon       city  \
#  0  44.43225  26.10626  Bucharest
#
#                                               weather
#  0  {'dt': 1656903600, 'temp': 13, 'wind': [{'wind...  ,
#          lat       lon      city  \
#  0  47.49835  19.04045  Budapest
#
#                                               weather
#  0  {'dt': 1656903600, 'temp': 40, 'wind': [{'wind...  ,
#          lat      lon     city  \
#  0  53.55073  9.99302  Hamburg
#
#                                               weather
#  0  {'dt': 1656903600, 'temp': 8, 'wind': [{'wind_...  ,
#          lat       lon      city  \
#  0  41.01384  28.94966  Istanbul
#
#                                               weather
#  0  {'dt': 1656903600, 'temp': 43, 'wind': [{'wind...  ,
#      lat       lon   city                                            weather
#  0  53.9  27.56667  Minsk  {'dt': 1656903600, 'temp': -29, 'wind': [{'win...,
#          lat       lon    city  \
#  0  55.75222  37.61556  Moscow
#
#                                               weather
#  0  {'dt': 1656903600, 'temp': 19, 'wind': [{'wind...  ,
#          lat     lon   city                                            weather
#  0  48.85341  2.3488  Paris  {'dt': 1656903600, 'temp': -30, 'wind': [{'win...,
#          lat       lon  city                                            weather
#  0  41.89193  12.51133  Rome  {'dt': 1656903600, 'temp': -10, 'wind': [{'win...,
#          lat       lon              city  \
#  0  59.93863  30.31413  Saint Petersburg
#
#                                               weather
#  0  {'dt': 1656903600, 'temp': -1, 'wind': [{'wind...  ,
#          lat       lon       city  \
#  0  59.32938  18.06871  Stockholm
#
#                                               weather
#  0  {'dt': 1656903600, 'temp': -8, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  48.20849  16.37208  Vienna
#
#                                               weather
#  0  {'dt': 1656903600, 'temp': 39, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  52.22977  21.01178  Warsaw
#
#                                               weather
#  0  {'dt': 1656903600, 'temp': -14, 'wind': [{'win...  ,
#          lat       lon    city  \
#  0  39.91987  32.85427  Ankara
#
#                                               weather
#  0  {'dt': 1656907200, 'temp': 19, 'wind': [{'wind...  ,
#          lat      lon       city  \
#  0  41.38879  2.15899  Barcelona
#
#                                               weather
#  0  {'dt': 1656907200, 'temp': -6, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  52.52437  13.41053  Berlin
#
#                                               weather
#  0  {'dt': 1656907200, 'temp': -26, 'wind': [{'win...  ,
#          lat       lon       city  \
#  0  44.43225  26.10626  Bucharest
#
#                                               weather
#  0  {'dt': 1656907200, 'temp': -10, 'wind': [{'win...  ,
#          lat       lon      city  \
#  0  47.49835  19.04045  Budapest
#
#                                               weather
#  0  {'dt': 1656907200, 'temp': -24, 'wind': [{'win...  ,
#          lat       lon      city  \
#  0  41.01384  28.94966  Istanbul
#
#                                               weather
#  0  {'dt': 1656907200, 'temp': -2, 'wind': [{'wind...  ,
#          lat      lon  city                                            weather
#  0  50.45466  30.5238  Kyiv  {'dt': 1656907200, 'temp': 11, 'wind': [{'wind...,
#          lat      lon    city  \
#  0  51.50853 -0.12574  London
#
#                                               weather
#  0  {'dt': 1656907200, 'temp': 50, 'wind': [{'wind...  ,
#         lat      lon    city                                            weather
#  0  40.4165 -3.70256  Madrid  {'dt': 1656907200, 'temp': -6, 'wind': [{'wind...,
#      lat       lon   city                                            weather
#  0  53.9  27.56667  Minsk  {'dt': 1656907200, 'temp': -13, 'wind': [{'win...,
#          lat       lon    city  \
#  0  55.75222  37.61556  Moscow
#
#                                               weather
#  0  {'dt': 1656907200, 'temp': 24, 'wind': [{'wind...  ,
#          lat     lon   city                                            weather
#  0  48.85341  2.3488  Paris  {'dt': 1656907200, 'temp': -29, 'wind': [{'win...,
#          lat       lon  city                                            weather
#  0  41.89193  12.51133  Rome  {'dt': 1656907200, 'temp': 41, 'wind': [{'wind...,
#          lat       lon              city  \
#  0  59.93863  30.31413  Saint Petersburg
#
#                                               weather
#  0  {'dt': 1656907200, 'temp': 33, 'wind': [{'wind...  ,
#          lat       lon       city  \
#  0  59.32938  18.06871  Stockholm
#
#                                               weather
#  0  {'dt': 1656907200, 'temp': 41, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  48.20849  16.37208  Vienna
#
#                                               weather
#  0  {'dt': 1656907200, 'temp': 5, 'wind': [{'wind_...  ,
#          lat       lon    city  \
#  0  52.22977  21.01178  Warsaw
#
#                                               weather
#  0  {'dt': 1656907200, 'temp': 1, 'wind': [{'wind_...  ,
#          lat       lon    city  \
#  0  39.91987  32.85427  Ankara
#
#                                               weather
#  0  {'dt': 1656910800, 'temp': 49, 'wind': [{'wind...  ,
#          lat      lon       city  \
#  0  41.38879  2.15899  Barcelona
#
#                                               weather
#  0  {'dt': 1656910800, 'temp': 44, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  52.52437  13.41053  Berlin
#
#                                               weather
#  0  {'dt': 1656910800, 'temp': 4, 'wind': [{'wind_...  ,
#          lat       lon       city  \
#  0  44.43225  26.10626  Bucharest
#
#                                               weather
#  0  {'dt': 1656910800, 'temp': 25, 'wind': [{'wind...  ,
#          lat       lon      city  \
#  0  41.01384  28.94966  Istanbul
#
#                                               weather
#  0  {'dt': 1656910800, 'temp': 29, 'wind': [{'wind...  ,
#          lat      lon  city                                            weather
#  0  50.45466  30.5238  Kyiv  {'dt': 1656910800, 'temp': -1, 'wind': [{'wind...,
#      lat       lon   city                                            weather
#  0  53.9  27.56667  Minsk  {'dt': 1656910800, 'temp': 25, 'wind': [{'wind...,
#          lat       lon    city  \
#  0  55.75222  37.61556  Moscow
#
#                                               weather
#  0  {'dt': 1656910800, 'temp': -24, 'wind': [{'win...  ,
#          lat     lon   city                                            weather
#  0  48.85341  2.3488  Paris  {'dt': 1656910800, 'temp': -8, 'wind': [{'wind...,
#          lat       lon              city  \
#  0  59.93863  30.31413  Saint Petersburg
#
#                                               weather
#  0  {'dt': 1656910800, 'temp': -19, 'wind': [{'win...  ,
#          lat       lon    city  \
#  0  48.20849  16.37208  Vienna
#
#                                               weather
#  0  {'dt': 1656910800, 'temp': -1, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  52.22977  21.01178  Warsaw
#
#                                               weather
#  0  {'dt': 1656910800, 'temp': 3, 'wind': [{'wind_...  ,
#          lat       lon    city  \
#  0  39.91987  32.85427  Ankara
#
#                                               weather
#  0  {'dt': 1656914400, 'temp': -21, 'wind': [{'win...  ,
#          lat      lon       city  \
#  0  41.38879  2.15899  Barcelona
#
#                                               weather
#  0  {'dt': 1656914400, 'temp': 15, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  52.52437  13.41053  Berlin
#
#                                               weather
#  0  {'dt': 1656914400, 'temp': 31, 'wind': [{'wind...  ,
#          lat       lon      city  \
#  0  47.49835  19.04045  Budapest
#
#                                               weather
#  0  {'dt': 1656914400, 'temp': 50, 'wind': [{'wind...  ,
#          lat      lon     city  \
#  0  53.55073  9.99302  Hamburg
#
#                                               weather
#  0  {'dt': 1656914400, 'temp': 44, 'wind': [{'wind...  ,
#          lat       lon      city  \
#  0  41.01384  28.94966  Istanbul
#
#                                               weather
#  0  {'dt': 1656914400, 'temp': 19, 'wind': [{'wind...  ,
#          lat      lon  city                                            weather
#  0  50.45466  30.5238  Kyiv  {'dt': 1656914400, 'temp': 4, 'wind': [{'wind_...,
#          lat      lon    city  \
#  0  51.50853 -0.12574  London
#
#                                               weather
#  0  {'dt': 1656914400, 'temp': 50, 'wind': [{'wind...  ,
#         lat      lon    city                                            weather
#  0  40.4165 -3.70256  Madrid  {'dt': 1656914400, 'temp': 37, 'wind': [{'wind...,
#          lat       lon    city  \
#  0  55.75222  37.61556  Moscow
#
#                                               weather
#  0  {'dt': 1656914400, 'temp': 7, 'wind': [{'wind_...  ,
#          lat     lon   city                                            weather
#  0  48.85341  2.3488  Paris  {'dt': 1656914400, 'temp': 35, 'wind': [{'wind...,
#          lat       lon  city                                            weather
#  0  41.89193  12.51133  Rome  {'dt': 1656914400, 'temp': 33, 'wind': [{'wind...,
#          lat       lon              city  \
#  0  59.93863  30.31413  Saint Petersburg
#
#                                               weather
#  0  {'dt': 1656914400, 'temp': 2, 'wind': [{'wind_...  ,
#          lat       lon       city  \
#  0  59.32938  18.06871  Stockholm
#
#                                               weather
#  0  {'dt': 1656914400, 'temp': -15, 'wind': [{'win...  ,
#          lat       lon    city  \
#  0  48.20849  16.37208  Vienna
#
#                                               weather
#  0  {'dt': 1656914400, 'temp': 39, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  52.22977  21.01178  Warsaw
#
#                                               weather
#  0  {'dt': 1656914400, 'temp': 15, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  39.91987  32.85427  Ankara
#
#                                               weather
#  0  {'dt': 1656918000, 'temp': 18, 'wind': [{'wind...  ,
#          lat      lon       city  \
#  0  41.38879  2.15899  Barcelona
#
#                                               weather
#  0  {'dt': 1656918000, 'temp': 6, 'wind': [{'wind_...  ,
#          lat       lon       city  \
#  0  44.43225  26.10626  Bucharest
#
#                                               weather
#  0  {'dt': 1656918000, 'temp': -28, 'wind': [{'win...  ,
#          lat       lon      city  \
#  0  47.49835  19.04045  Budapest
#
#                                               weather
#  0  {'dt': 1656918000, 'temp': 46, 'wind': [{'wind...  ,
#          lat      lon     city  \
#  0  53.55073  9.99302  Hamburg
#
#                                               weather
#  0  {'dt': 1656918000, 'temp': 3, 'wind': [{'wind_...  ,
#          lat      lon  city                                            weather
#  0  50.45466  30.5238  Kyiv  {'dt': 1656918000, 'temp': 40, 'wind': [{'wind...,
#          lat      lon    city  \
#  0  51.50853 -0.12574  London
#
#                                               weather
#  0  {'dt': 1656918000, 'temp': 23, 'wind': [{'wind...  ,
#         lat      lon    city                                            weather
#  0  40.4165 -3.70256  Madrid  {'dt': 1656918000, 'temp': 30, 'wind': [{'wind...,
#      lat       lon   city                                            weather
#  0  53.9  27.56667  Minsk  {'dt': 1656918000, 'temp': 24, 'wind': [{'wind...,
#          lat       lon    city  \
#  0  55.75222  37.61556  Moscow
#
#                                               weather
#  0  {'dt': 1656918000, 'temp': 40, 'wind': [{'wind...  ,
#          lat     lon   city                                            weather
#  0  48.85341  2.3488  Paris  {'dt': 1656918000, 'temp': -30, 'wind': [{'win...,
#          lat       lon  city                                            weather
#  0  41.89193  12.51133  Rome  {'dt': 1656918000, 'temp': 15, 'wind': [{'wind...,
#          lat       lon    city  \
#  0  48.20849  16.37208  Vienna
#
#                                               weather
#  0  {'dt': 1656918000, 'temp': 24, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  52.22977  21.01178  Warsaw
#
#                                               weather
#  0  {'dt': 1656918000, 'temp': 3, 'wind': [{'wind_...  ,
#          lat       lon    city  \
#  0  39.91987  32.85427  Ankara
#
#                                               weather
#  0  {'dt': 1656921600, 'temp': -25, 'wind': [{'win...  ,
#          lat      lon       city  \
#  0  41.38879  2.15899  Barcelona
#
#                                               weather
#  0  {'dt': 1656921600, 'temp': -2, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  52.52437  13.41053  Berlin
#
#                                               weather
#  0  {'dt': 1656921600, 'temp': 9, 'wind': [{'wind_...  ,
#          lat       lon       city  \
#  0  44.43225  26.10626  Bucharest
#
#                                               weather
#  0  {'dt': 1656921600, 'temp': -1, 'wind': [{'wind...  ,
#          lat       lon      city  \
#  0  47.49835  19.04045  Budapest
#
#                                               weather
#  0  {'dt': 1656921600, 'temp': 5, 'wind': [{'wind_...  ,
#          lat      lon     city  \
#  0  53.55073  9.99302  Hamburg
#
#                                               weather
#  0  {'dt': 1656921600, 'temp': 6, 'wind': [{'wind_...  ,
#          lat       lon      city  \
#  0  41.01384  28.94966  Istanbul
#
#                                               weather
#  0  {'dt': 1656921600, 'temp': 10, 'wind': [{'wind...  ,
#          lat      lon    city  \
#  0  51.50853 -0.12574  London
#
#                                               weather
#  0  {'dt': 1656921600, 'temp': -9, 'wind': [{'wind...  ,
#         lat      lon    city                                            weather
#  0  40.4165 -3.70256  Madrid  {'dt': 1656921600, 'temp': -25, 'wind': [{'win...,
#      lat       lon   city                                            weather
#  0  53.9  27.56667  Minsk  {'dt': 1656921600, 'temp': 22, 'wind': [{'wind...,
#          lat       lon    city  \
#  0  55.75222  37.61556  Moscow
#
#                                               weather
#  0  {'dt': 1656921600, 'temp': -13, 'wind': [{'win...  ,
#          lat     lon   city                                            weather
#  0  48.85341  2.3488  Paris  {'dt': 1656921600, 'temp': 15, 'wind': [{'wind...,
#          lat       lon       city  \
#  0  59.32938  18.06871  Stockholm
#
#                                               weather
#  0  {'dt': 1656921600, 'temp': 12, 'wind': [{'wind...  ,
#          lat       lon    city  \
#  0  48.20849  16.37208  Vienna
#
#                                               weather
#  0  {'dt': 1656921600, 'temp': 8, 'wind': [{'wind_...  ,
#  ...]

# %%
#Concatenating everything into a single dataframe

df = pd.concat(data, ignore_index=True)

df
# Out:
#             lat       lon      city  \
# 0      47.49835  19.04045  Budapest
# 1      40.41650  -3.70256    Madrid
# 2      53.90000  27.56667     Minsk
# 3      55.75222  37.61556    Moscow
# 4      52.22977  21.01178    Warsaw
# ...         ...       ...       ...
# 10135  51.50853  -0.12574    London
# 10136  40.41650  -3.70256    Madrid
# 10137  40.41650  -3.70256    Madrid
# 10138  55.75222  37.61556    Moscow
# 10139  40.41650  -3.70256    Madrid
#
#                                                  weather
# 0      {'dt': 1656637200, 'temp': -11, 'wind': [{'win...
# 1      {'dt': 1656637200, 'temp': 46, 'wind': [{'wind...
# 2      {'dt': 1656637200, 'temp': 5, 'wind': [{'wind_...
# 3      {'dt': 1656637200, 'temp': 45, 'wind': [{'wind...
# 4      {'dt': 1656637200, 'temp': 22, 'wind': [{'wind...
# ...                                                  ...
# 10135  {'dt': 1659384000, 'temp': -13, 'wind': [{'win...
# 10136  {'dt': 1659384000, 'temp': -2, 'wind': [{'wind...
# 10137  {'dt': 1659394800, 'temp': -27, 'wind': [{'win...
# 10138  {'dt': 1659402000, 'temp': 37, 'wind': [{'wind...
# 10139  {'dt': 1659427200, 'temp': 3, 'wind': [{'wind_...
#
# [10140 rows x 4 columns]

# %% [markdown]
# 1. Flattening:
#
# Our first challenge is to flatten the data, since relevant values are in a struct form.

# %%
#First I normalize the first level of the wind column
from pandas import json_normalize


df = df.join(json_normalize(df['weather'].to_list()))\
       .drop(['weather'], axis=1)

df
# Out:
#             lat       lon      city          dt  temp  \
# 0      47.49835  19.04045  Budapest  1656637200   -11
# 1      40.41650  -3.70256    Madrid  1656637200    46
# 2      53.90000  27.56667     Minsk  1656637200     5
# 3      55.75222  37.61556    Moscow  1656637200    45
# 4      52.22977  21.01178    Warsaw  1656637200    22
# ...         ...       ...       ...         ...   ...
# 10135  51.50853  -0.12574    London  1659384000   -13
# 10136  40.41650  -3.70256    Madrid  1659384000    -2
# 10137  40.41650  -3.70256    Madrid  1659394800   -27
# 10138  55.75222  37.61556    Moscow  1659402000    37
# 10139  40.41650  -3.70256    Madrid  1659427200     3
#
#                                           wind  clouds  humidity  pressure  \
# 0       [{'wind_deg': -9.9, 'wind_speed': 95}]       6        23      1013
# 1       [{'wind_deg': 41.4, 'wind_speed': 17}]     100        15      1019
# 2        [{'wind_deg': 4.5, 'wind_speed': 74}]      47        27      1009
# 3       [{'wind_deg': 40.5, 'wind_speed': 68}]      51        24      1015
# 4       [{'wind_deg': 19.8, 'wind_speed': 25}]      92        13      1007
# ...                                        ...     ...       ...       ...
# 10135  [{'wind_deg': -11.7, 'wind_speed': 95}]      51        15      1005
# 10136   [{'wind_deg': -1.8, 'wind_speed': 98}]      43        22      1019
# 10137  [{'wind_deg': -24.3, 'wind_speed': 29}]      88        18      1007
# 10138   [{'wind_deg': 33.3, 'wind_speed': 75}]      65        13      1016
# 10139    [{'wind_deg': 2.7, 'wind_speed': 88}]      99        15      1009
#
#        feels_like  visibility
# 0           -12.1       10000
# 1            50.6       10000
# 2             5.5       10000
# 3            49.5       10000
# 4            24.2       10000
# ...           ...         ...
# 10135       -14.3       10000
# 10136        -2.2       10000
# 10137       -29.7       10000
# 10138        40.7       10000
# 10139         3.3       10000
#
# [10140 rows x 11 columns]

# %%
#Normalize to enter into the second level
df = df.join(json_normalize(df['wind'].to_list()))\
       .drop(['wind'], axis=1)

df
# Out:
#             lat       lon      city          dt  temp  clouds  humidity  \
# 0      47.49835  19.04045  Budapest  1656637200   -11       6        23
# 1      40.41650  -3.70256    Madrid  1656637200    46     100        15
# 2      53.90000  27.56667     Minsk  1656637200     5      47        27
# 3      55.75222  37.61556    Moscow  1656637200    45      51        24
# 4      52.22977  21.01178    Warsaw  1656637200    22      92        13
# ...         ...       ...       ...         ...   ...     ...       ...
# 10135  51.50853  -0.12574    London  1659384000   -13      51        15
# 10136  40.41650  -3.70256    Madrid  1659384000    -2      43        22
# 10137  40.41650  -3.70256    Madrid  1659394800   -27      88        18
# 10138  55.75222  37.61556    Moscow  1659402000    37      65        13
# 10139  40.41650  -3.70256    Madrid  1659427200     3      99        15
#
#        pressure  feels_like  visibility                                      0
# 0          1013       -12.1       10000   {'wind_deg': -9.9, 'wind_speed': 95}
# 1          1019        50.6       10000   {'wind_deg': 41.4, 'wind_speed': 17}
# 2          1009         5.5       10000    {'wind_deg': 4.5, 'wind_speed': 74}
# 3          1015        49.5       10000   {'wind_deg': 40.5, 'wind_speed': 68}
# 4          1007        24.2       10000   {'wind_deg': 19.8, 'wind_speed': 25}
# ...         ...         ...         ...                                    ...
# 10135      1005       -14.3       10000  {'wind_deg': -11.7, 'wind_speed': 95}
# 10136      1019        -2.2       10000   {'wind_deg': -1.8, 'wind_speed': 98}
# 10137      1007       -29.7       10000  {'wind_deg': -24.3, 'wind_speed': 29}
# 10138      1016        40.7       10000   {'wind_deg': 33.3, 'wind_speed': 75}
# 10139      1009         3.3       10000    {'wind_deg': 2.7, 'wind_speed': 88}
#
# [10140 rows x 11 columns]

# %%
#Getting into the wind information
df = df.join(json_normalize(df[0].to_list()))\
       .drop([0], axis=1)

df
# Out:
#             lat       lon      city          dt  temp  clouds  humidity  \
# 0      47.49835  19.04045  Budapest  1656637200   -11       6        23
# 1      40.41650  -3.70256    Madrid  1656637200    46     100        15
# 2      53.90000  27.56667     Minsk  1656637200     5      47        27
# 3      55.75222  37.61556    Moscow  1656637200    45      51        24
# 4      52.22977  21.01178    Warsaw  1656637200    22      92        13
# ...         ...       ...       ...         ...   ...     ...       ...
# 10135  51.50853  -0.12574    London  1659384000   -13      51        15
# 10136  40.41650  -3.70256    Madrid  1659384000    -2      43        22
# 10137  40.41650  -3.70256    Madrid  1659394800   -27      88        18
# 10138  55.75222  37.61556    Moscow  1659402000    37      65        13
# 10139  40.41650  -3.70256    Madrid  1659427200     3      99        15
#
#        pressure  feels_like  visibility  wind_deg  wind_speed
# 0          1013       -12.1       10000      -9.9          95
# 1          1019        50.6       10000      41.4          17
# 2          1009         5.5       10000       4.5          74
# 3          1015        49.5       10000      40.5          68
# 4          1007        24.2       10000      19.8          25
# ...         ...         ...         ...       ...         ...
# 10135      1005       -14.3       10000     -11.7          95
# 10136      1019        -2.2       10000      -1.8          98
# 10137      1007       -29.7       10000     -24.3          29
# 10138      1016        40.7       10000      33.3          75
# 10139      1009         3.3       10000       2.7          88
#
# [10140 rows x 12 columns]

# %% [markdown]
# 2. DateTime Format:
#
#  Datetime data is in an Epoch format, in order to be human readable we need to transform it into a datetime format.

# %%
#Time was in Epoch format so we need to change it into datetime

import datetime

df['dt'] = pd.to_datetime(df['dt'], unit='s')

df
# Out:
#             lat       lon      city                  dt  temp  clouds  \
# 0      47.49835  19.04045  Budapest 2022-07-01 01:00:00   -11       6
# 1      40.41650  -3.70256    Madrid 2022-07-01 01:00:00    46     100
# 2      53.90000  27.56667     Minsk 2022-07-01 01:00:00     5      47
# 3      55.75222  37.61556    Moscow 2022-07-01 01:00:00    45      51
# 4      52.22977  21.01178    Warsaw 2022-07-01 01:00:00    22      92
# ...         ...       ...       ...                 ...   ...     ...
# 10135  51.50853  -0.12574    London 2022-08-01 20:00:00   -13      51
# 10136  40.41650  -3.70256    Madrid 2022-08-01 20:00:00    -2      43
# 10137  40.41650  -3.70256    Madrid 2022-08-01 23:00:00   -27      88
# 10138  55.75222  37.61556    Moscow 2022-08-02 01:00:00    37      65
# 10139  40.41650  -3.70256    Madrid 2022-08-02 08:00:00     3      99
#
#        humidity  pressure  feels_like  visibility  wind_deg  wind_speed
# 0            23      1013       -12.1       10000      -9.9          95
# 1            15      1019        50.6       10000      41.4          17
# 2            27      1009         5.5       10000       4.5          74
# 3            24      1015        49.5       10000      40.5          68
# 4            13      1007        24.2       10000      19.8          25
# ...         ...       ...         ...         ...       ...         ...
# 10135        15      1005       -14.3       10000     -11.7          95
# 10136        22      1019        -2.2       10000      -1.8          98
# 10137        18      1007       -29.7       10000     -24.3          29
# 10138        13      1016        40.7       10000      33.3          75
# 10139        15      1009         3.3       10000       2.7          88
#
# [10140 rows x 12 columns]

# %% [markdown]
# 3. Sinking weather into Data Lake:
#
# The sink is being performed into parquet format and compressed in snappy in order to optimize performance and the storage use

# %%
#Sinking the clean data into the datalake, partitioned by city

df.to_parquet('C:/Users/E.ALVAREZHERNANDEZ/VS Projects/caseStudy/clean_data/weather/',compression='snappy', partition_cols='city')

# %% [markdown]
# 4. Delta weather table:
#
# As we recreate the data from the datalake parquet files the processing times improves, from 56 secs to 0.1 secs and the storage use from 2.26 MB to 320 KB, it reduces the size by 84%

# %%
#Pulling clean weather temperature

cweather = pd.read_parquet('C:/Users/E.ALVAREZHERNANDEZ/VS Projects/caseStudy/clean_data/weather')

cweather
# Out:
#            lat       lon                  dt  temp  clouds  humidity  \
# 4508  47.49835  19.04045 2022-07-01 01:00:00   -11       6        23
# 4509  47.49835  19.04045 2022-07-01 03:00:00   -14      12        30
# 4510  47.49835  19.04045 2022-07-01 05:00:00    20      91        11
# 4511  47.49835  19.04045 2022-07-01 08:00:00    -9      33        29
# 4512  47.49835  19.04045 2022-07-01 09:00:00    34      50        24
# ...        ...       ...                 ...   ...     ...       ...
# 5647  47.49835  19.04045 2022-07-31 18:00:00     8      57        22
# 5648  47.49835  19.04045 2022-07-31 19:00:00    32      49        26
# 5649  47.49835  19.04045 2022-07-31 21:00:00    40      73        19
# 5650  47.49835  19.04045 2022-07-31 22:00:00    13      14        24
# 5651  47.49835  19.04045 2022-08-01 09:00:00    -8      42        14
#
#       pressure  feels_like  visibility  wind_deg  wind_speed      city
# 4508      1013       -12.1       10000      -9.9          95  Budapest
# 4509      1019       -15.4       10000     -12.6          35  Budapest
# 4510      1006        22.0       10000      18.0          86  Budapest
# 4511      1006        -9.9       10000      -8.1          15  Budapest
# 4512      1007        37.4       10000      30.6          48  Budapest
# ...        ...         ...         ...       ...         ...       ...
# 5647      1017         8.8       10000       7.2          77  Budapest
# 5648      1015        35.2       10000      28.8          63  Budapest
# 5649      1017        44.0       10000      36.0          87  Budapest
# 5650      1011        14.3       10000      11.7          20  Budapest
# 5651      1016        -8.8       10000      -7.2          32  Budapest
#
# [1144 rows x 12 columns]

# %%
#In order to get the avg temperature I will subset

temperature = cweather[['dt', 'temp', 'city']]

temperature
# Out:
#                        dt  temp    city
# 0     2022-07-01 02:00:00    48  Ankara
# 1     2022-07-01 03:00:00    26  Ankara
# 2     2022-07-01 05:00:00   -26  Ankara
# 3     2022-07-01 06:00:00    10  Ankara
# 4     2022-07-01 10:00:00   -18  Ankara
# ...                   ...   ...     ...
# 20275 2022-07-31 11:00:00    37  Warsaw
# 20276 2022-07-31 12:00:00    24  Warsaw
# 20277 2022-07-31 14:00:00    -6  Warsaw
# 20278 2022-07-31 16:00:00    -5  Warsaw
# 20279 2022-07-31 17:00:00   -27  Warsaw
#
# [20280 rows x 3 columns]

# %% [markdown]
# 5. Connecting with shipments DB:

# %%
import psycopg2
import logging

conn = psycopg2.connect(host='localhost',
                        database='bttf',
                        user='postgres',
                        password='Zurich2022!',
                        port='5432')

# %%
pointer = conn.cursor()

pointer.execute("SELECT * FROM shipments.shipments")

rows = pointer.fetchall() #Tupple format

# %%
shdf = pd.DataFrame(rows, columns=['id', 'truck', 'driver', 'shipment_start_timestamp', 'shipment_end_timestamp', 'start_location', 'end_location', 'shipment_distance', 'consumed_fuel'])
shdf
# Out:
#         id  truck  driver   shipment_start_timestamp  \
# 0     9919   6305    4272 2022-07-29 20:12:53.027776
# 1     9963   6931    3438 2022-07-23 19:33:42.412344
# 2     9969   2514    4797 2022-07-29 18:01:08.431993
# 3     9913   2531    9127 2022-07-06 00:16:40.813996
# 4     9691   9035    7504 2022-07-18 01:01:13.147528
# ...    ...    ...     ...                        ...
# 9440  1193   9871    3150 2022-07-28 11:45:55.328784
# 9441   875   9443    1055 2022-07-10 20:16:38.103979
# 9442   462   6301    2606 2022-07-19 10:22:46.344214
# 9443   388   8058    4739 2022-07-03 20:23:03.033107
# 9444   121   8171    5326 2022-07-28 21:38:40.753101
#
#          shipment_end_timestamp start_location end_location  \
# 0    2022-07-30 22:52:32.903400        Hamburg    Barcelona
# 1    2022-07-25 07:43:57.066507        Hamburg       Ankara
# 2    2022-07-30 06:24:11.660956        Hamburg       London
# 3    2022-07-06 14:22:57.521956        Hamburg    Stockholm
# 4    2022-07-18 17:31:10.597189        Hamburg     Budapest
# ...                         ...            ...          ...
# 9440 2022-07-28 20:12:33.632634         Vienna       Warsaw
# 9441 2022-07-11 04:53:11.526090         Vienna       Warsaw
# 9442 2022-07-19 19:27:31.316003         Vienna       Warsaw
# 9443 2022-07-04 05:38:58.188670         Vienna       Warsaw
# 9444 2022-07-29 06:53:25.469212         Vienna       Warsaw
#
#       shipment_distance  consumed_fuel
# 0            1769.40660         342.89
# 1            2752.17850         506.77
# 2             865.48140         161.01
# 3             974.03534         180.04
# 4            1113.69500         204.33
# ...                 ...            ...
# 9440          667.40424         111.79
# 9441          667.40424         117.95
# 9442          667.40424         118.04
# 9443          667.40424         115.37
# 9444          667.40424         114.60
#
# [9445 rows x 9 columns]

# %% [markdown]
# 6. Fixing shipments timestamp formats:
#
# Asumption: Weather doesn't have a big variance from hour to hour, so to facilitate the analysis I'm going to round the shipment hours to the closest hour.

# %%
#Dates are in sql format, so in here I invert them to match the df convention

import datetime


shdf['shipment_start_timestamp'] = pd.to_datetime(shdf['shipment_start_timestamp'] ).apply(lambda x: datetime.datetime.strftime(x, '%Y-%m-%d %H:%M:%S'))
shdf['shipment_end_timestamp'] = pd.to_datetime(shdf['shipment_end_timestamp'] ).apply(lambda x: datetime.datetime.strftime(x, '%Y-%m-%d %H:%M:%S'))
shdf['shipment_start_timestamp'] = pd.to_datetime(shdf['shipment_start_timestamp'])
shdf['shipment_end_timestamp'] = pd.to_datetime(shdf['shipment_end_timestamp'])



shdf
# Out:
#         id  truck  driver shipment_start_timestamp shipment_end_timestamp  \
# 0     9919   6305    4272      2022-07-29 20:12:53    2022-07-30 22:52:32
# 1     9963   6931    3438      2022-07-23 19:33:42    2022-07-25 07:43:57
# 2     9969   2514    4797      2022-07-29 18:01:08    2022-07-30 06:24:11
# 3     9913   2531    9127      2022-07-06 00:16:40    2022-07-06 14:22:57
# 4     9691   9035    7504      2022-07-18 01:01:13    2022-07-18 17:31:10
# ...    ...    ...     ...                      ...                    ...
# 9440  1193   9871    3150      2022-07-28 11:45:55    2022-07-28 20:12:33
# 9441   875   9443    1055      2022-07-10 20:16:38    2022-07-11 04:53:11
# 9442   462   6301    2606      2022-07-19 10:22:46    2022-07-19 19:27:31
# 9443   388   8058    4739      2022-07-03 20:23:03    2022-07-04 05:38:58
# 9444   121   8171    5326      2022-07-28 21:38:40    2022-07-29 06:53:25
#
#      start_location end_location  shipment_distance  consumed_fuel
# 0           Hamburg    Barcelona         1769.40660         342.89
# 1           Hamburg       Ankara         2752.17850         506.77
# 2           Hamburg       London          865.48140         161.01
# 3           Hamburg    Stockholm          974.03534         180.04
# 4           Hamburg     Budapest         1113.69500         204.33
# ...             ...          ...                ...            ...
# 9440         Vienna       Warsaw          667.40424         111.79
# 9441         Vienna       Warsaw          667.40424         117.95
# 9442         Vienna       Warsaw          667.40424         118.04
# 9443         Vienna       Warsaw          667.40424         115.37
# 9444         Vienna       Warsaw          667.40424         114.60
#
# [9445 rows x 9 columns]

# %%
shdf['shipment_start_timestamp'] = shdf['shipment_start_timestamp'].dt.round('H')
shdf['shipment_end_timestamp'] = shdf['shipment_end_timestamp'].dt.round('H')
shdf['fConsumption']= (shdf['consumed_fuel']*100)/shdf['shipment_distance']
shdf
# Out:
#         id  truck  driver shipment_start_timestamp shipment_end_timestamp  \
# 0     9919   6305    4272      2022-07-29 20:00:00    2022-07-30 23:00:00
# 1     9963   6931    3438      2022-07-23 20:00:00    2022-07-25 08:00:00
# 2     9969   2514    4797      2022-07-29 18:00:00    2022-07-30 06:00:00
# 3     9913   2531    9127      2022-07-06 00:00:00    2022-07-06 14:00:00
# 4     9691   9035    7504      2022-07-18 01:00:00    2022-07-18 18:00:00
# ...    ...    ...     ...                      ...                    ...
# 9440  1193   9871    3150      2022-07-28 12:00:00    2022-07-28 20:00:00
# 9441   875   9443    1055      2022-07-10 20:00:00    2022-07-11 05:00:00
# 9442   462   6301    2606      2022-07-19 10:00:00    2022-07-19 19:00:00
# 9443   388   8058    4739      2022-07-03 20:00:00    2022-07-04 06:00:00
# 9444   121   8171    5326      2022-07-28 22:00:00    2022-07-29 07:00:00
#
#      start_location end_location  shipment_distance  consumed_fuel  \
# 0           Hamburg    Barcelona         1769.40660         342.89
# 1           Hamburg       Ankara         2752.17850         506.77
# 2           Hamburg       London          865.48140         161.01
# 3           Hamburg    Stockholm          974.03534         180.04
# 4           Hamburg     Budapest         1113.69500         204.33
# ...             ...          ...                ...            ...
# 9440         Vienna       Warsaw          667.40424         111.79
# 9441         Vienna       Warsaw          667.40424         117.95
# 9442         Vienna       Warsaw          667.40424         118.04
# 9443         Vienna       Warsaw          667.40424         115.37
# 9444         Vienna       Warsaw          667.40424         114.60
#
#       fConsumption
# 0        19.378813
# 1        18.413413
# 2        18.603519
# 3        18.483929
# 4        18.347034
# ...            ...
# 9440     16.749969
# 9441     17.672947
# 9442     17.686432
# 9443     17.286375
# 9444     17.171003
#
# [9445 rows x 10 columns]

# %% [markdown]
# 7. Merging data:
#
# In this step we merge the dataframes to get the weather conditions at location and time for the shipments

# %%
#Merging to get the first temperature matching the start location and the start timestamp


dfmerge = pd.merge(shdf, temperature, how='left', left_on=[shdf['start_location'].astype(str), shdf['shipment_start_timestamp'].astype(str)], right_on=[temperature['city'].astype(str), temperature['dt'].astype(str)])
dfmerge= dfmerge.rename(columns={'temp':'startTemp'}).drop(['key_0', 'key_1', 'city', 'dt'], axis=1)

dfmerge
# Out:
#          id  truck  driver shipment_start_timestamp shipment_end_timestamp  \
# 0      9919   6305    4272      2022-07-29 20:00:00    2022-07-30 23:00:00
# 1      9919   6305    4272      2022-07-29 20:00:00    2022-07-30 23:00:00
# 2      9963   6931    3438      2022-07-23 20:00:00    2022-07-25 08:00:00
# 3      9969   2514    4797      2022-07-29 18:00:00    2022-07-30 06:00:00
# 4      9969   2514    4797      2022-07-29 18:00:00    2022-07-30 06:00:00
# ...     ...    ...     ...                      ...                    ...
# 17768   462   6301    2606      2022-07-19 10:00:00    2022-07-19 19:00:00
# 17769   388   8058    4739      2022-07-03 20:00:00    2022-07-04 06:00:00
# 17770   388   8058    4739      2022-07-03 20:00:00    2022-07-04 06:00:00
# 17771   121   8171    5326      2022-07-28 22:00:00    2022-07-29 07:00:00
# 17772   121   8171    5326      2022-07-28 22:00:00    2022-07-29 07:00:00
#
#       start_location end_location  shipment_distance  consumed_fuel  \
# 0            Hamburg    Barcelona         1769.40660         342.89
# 1            Hamburg    Barcelona         1769.40660         342.89
# 2            Hamburg       Ankara         2752.17850         506.77
# 3            Hamburg       London          865.48140         161.01
# 4            Hamburg       London          865.48140         161.01
# ...              ...          ...                ...            ...
# 17768         Vienna       Warsaw          667.40424         118.04
# 17769         Vienna       Warsaw          667.40424         115.37
# 17770         Vienna       Warsaw          667.40424         115.37
# 17771         Vienna       Warsaw          667.40424         114.60
# 17772         Vienna       Warsaw          667.40424         114.60
#
#        fConsumption  startTemp
# 0         19.378813        3.0
# 1         19.378813        3.0
# 2         18.413413        NaN
# 3         18.603519       23.0
# 4         18.603519       23.0
# ...             ...        ...
# 17768     17.686432      -17.0
# 17769     17.286375       45.0
# 17770     17.286375       45.0
# 17771     17.171003       29.0
# 17772     17.171003       29.0
#
# [17773 rows x 11 columns]

# %%
#Merging to get the end temperature matching the end location and the end timestamp


dfmerge2 = pd.merge(dfmerge, temperature, how='left', left_on=[dfmerge['end_location'].astype(str), dfmerge['shipment_end_timestamp'].astype(str)], right_on=[temperature['city'].astype(str), temperature['dt'].astype(str)])
dfmerge2= dfmerge2.drop(['key_0', 'key_1', 'dt', 'city'], axis=1).rename(columns={'temp':'endTemp'})
dfmerge2
# Out:
#          id  truck  driver shipment_start_timestamp shipment_end_timestamp  \
# 0      9919   6305    4272      2022-07-29 20:00:00    2022-07-30 23:00:00
# 1      9919   6305    4272      2022-07-29 20:00:00    2022-07-30 23:00:00
# 2      9963   6931    3438      2022-07-23 20:00:00    2022-07-25 08:00:00
# 3      9963   6931    3438      2022-07-23 20:00:00    2022-07-25 08:00:00
# 4      9969   2514    4797      2022-07-29 18:00:00    2022-07-30 06:00:00
# ...     ...    ...     ...                      ...                    ...
# 33503   388   8058    4739      2022-07-03 20:00:00    2022-07-04 06:00:00
# 33504   121   8171    5326      2022-07-28 22:00:00    2022-07-29 07:00:00
# 33505   121   8171    5326      2022-07-28 22:00:00    2022-07-29 07:00:00
# 33506   121   8171    5326      2022-07-28 22:00:00    2022-07-29 07:00:00
# 33507   121   8171    5326      2022-07-28 22:00:00    2022-07-29 07:00:00
#
#       start_location end_location  shipment_distance  consumed_fuel  \
# 0            Hamburg    Barcelona         1769.40660         342.89
# 1            Hamburg    Barcelona         1769.40660         342.89
# 2            Hamburg       Ankara         2752.17850         506.77
# 3            Hamburg       Ankara         2752.17850         506.77
# 4            Hamburg       London          865.48140         161.01
# ...              ...          ...                ...            ...
# 33503         Vienna       Warsaw          667.40424         115.37
# 33504         Vienna       Warsaw          667.40424         114.60
# 33505         Vienna       Warsaw          667.40424         114.60
# 33506         Vienna       Warsaw          667.40424         114.60
# 33507         Vienna       Warsaw          667.40424         114.60
#
#        fConsumption  startTemp  endTemp
# 0         19.378813        3.0      NaN
# 1         19.378813        3.0      NaN
# 2         18.413413        NaN     -2.0
# 3         18.413413        NaN     -2.0
# 4         18.603519       23.0    -14.0
# ...             ...        ...      ...
# 33503     17.286375       45.0     15.0
# 33504     17.171003       29.0    -20.0
# 33505     17.171003       29.0    -20.0
# 33506     17.171003       29.0    -20.0
# 33507     17.171003       29.0    -20.0
#
# [33508 rows x 12 columns]

# %%
#Getting the average temperature for the trip, and setting the timestamp to datetime as it was required to pass them as strings for the merge

shipment = dfmerge2

shipment['avgTemp']= (shipment['startTemp']+shipment['endTemp'])/2

shipment['shipment_start_timestamp'] = pd.to_datetime(shipment['shipment_start_timestamp'])
shipment['shipment_end_timestamp'] = pd.to_datetime(shipment['shipment_end_timestamp'])

shipment['duration'] = (shipment['shipment_end_timestamp'] - shipment['shipment_start_timestamp']).astype('timedelta64[h]')

shipment
# Out:
#          id  truck  driver shipment_start_timestamp shipment_end_timestamp  \
# 0      9919   6305    4272      2022-07-29 20:00:00    2022-07-30 23:00:00
# 1      9919   6305    4272      2022-07-29 20:00:00    2022-07-30 23:00:00
# 2      9963   6931    3438      2022-07-23 20:00:00    2022-07-25 08:00:00
# 3      9963   6931    3438      2022-07-23 20:00:00    2022-07-25 08:00:00
# 4      9969   2514    4797      2022-07-29 18:00:00    2022-07-30 06:00:00
# ...     ...    ...     ...                      ...                    ...
# 33503   388   8058    4739      2022-07-03 20:00:00    2022-07-04 06:00:00
# 33504   121   8171    5326      2022-07-28 22:00:00    2022-07-29 07:00:00
# 33505   121   8171    5326      2022-07-28 22:00:00    2022-07-29 07:00:00
# 33506   121   8171    5326      2022-07-28 22:00:00    2022-07-29 07:00:00
# 33507   121   8171    5326      2022-07-28 22:00:00    2022-07-29 07:00:00
#
#       start_location end_location  shipment_distance  consumed_fuel  \
# 0            Hamburg    Barcelona         1769.40660         342.89
# 1            Hamburg    Barcelona         1769.40660         342.89
# 2            Hamburg       Ankara         2752.17850         506.77
# 3            Hamburg       Ankara         2752.17850         506.77
# 4            Hamburg       London          865.48140         161.01
# ...              ...          ...                ...            ...
# 33503         Vienna       Warsaw          667.40424         115.37
# 33504         Vienna       Warsaw          667.40424         114.60
# 33505         Vienna       Warsaw          667.40424         114.60
# 33506         Vienna       Warsaw          667.40424         114.60
# 33507         Vienna       Warsaw          667.40424         114.60
#
#        fConsumption  startTemp  endTemp  avgTemp  duration
# 0         19.378813        3.0      NaN      NaN      27.0
# 1         19.378813        3.0      NaN      NaN      27.0
# 2         18.413413        NaN     -2.0      NaN      36.0
# 3         18.413413        NaN     -2.0      NaN      36.0
# 4         18.603519       23.0    -14.0      4.5      12.0
# ...             ...        ...      ...      ...       ...
# 33503     17.286375       45.0     15.0     30.0      10.0
# 33504     17.171003       29.0    -20.0      4.5       9.0
# 33505     17.171003       29.0    -20.0      4.5       9.0
# 33506     17.171003       29.0    -20.0      4.5       9.0
# 33507     17.171003       29.0    -20.0      4.5       9.0
#
# [33508 rows x 14 columns]

# %%
#The correlation matrix shows some results already


shipment.corr()
# Out:
#                          id     truck    driver  shipment_distance  \
# id                 1.000000 -0.024621  0.008833          -0.002869
# truck             -0.024621  1.000000 -0.003559          -0.001682
# driver             0.008833 -0.003559  1.000000          -0.018203
# shipment_distance -0.002869 -0.001682 -0.018203           1.000000
# consumed_fuel     -0.002004  0.004865 -0.011565           0.942831
# fConsumption       0.002043  0.021662  0.020798          -0.133585
# startTemp         -0.010586  0.008407 -0.015152          -0.016421
# endTemp            0.010457 -0.006044 -0.016788           0.003567
# avgTemp            0.000072 -0.002425 -0.024272          -0.011248
# duration          -0.001907 -0.001353 -0.017358           0.991306
#
#                    consumed_fuel  fConsumption  startTemp   endTemp   avgTemp  \
# id                     -0.002004      0.002043  -0.010586  0.010457  0.000072
# truck                   0.004865      0.021662   0.008407 -0.006044 -0.002425
# driver                 -0.011565      0.020798  -0.015152 -0.016788 -0.024272
# shipment_distance       0.942831     -0.133585  -0.016421  0.003567 -0.011248
# consumed_fuel           1.000000      0.176680  -0.020436  0.005010 -0.013316
# fConsumption            0.176680      1.000000  -0.011944  0.007722 -0.003363
# startTemp              -0.020436     -0.011944   1.000000 -0.001402  0.705573
# endTemp                 0.005010      0.007722  -0.001402  1.000000  0.707647
# avgTemp                -0.013316     -0.003363   0.705573  0.707647  1.000000
# duration                0.934030     -0.134163  -0.015851  0.004325 -0.010078
#
#                    duration
# id                -0.001907
# truck             -0.001353
# driver            -0.017358
# shipment_distance  0.991306
# consumed_fuel      0.934030
# fConsumption      -0.134163
# startTemp         -0.015851
# endTemp            0.004325
# avgTemp           -0.010078
# duration           1.000000

# %%
#Sinking the clean data into the datalake


shipment.to_parquet('C:/Users/E.ALVAREZHERNANDEZ/VS Projects/caseStudy/clean_data/DataLake/gold.parquet',compression='snappy')

# %%
temperature['dt'].max()
# Out:
# Timestamp('2022-08-02 08:00:00')

# %%
import requests
import json



#barcelona = 41.38879	2.15899
#budapest = 47.49835	19.04045
apiKey= 'ffca9f02-39a7-11ed-93b0-0242ac130002-ffca9f70-39a7-11ed-93b0-0242ac130002' 
response = requests.get(
  'https://api.stormglass.io/v2/weather/point',
  params={
    'lat': 41.38879,
    'lng': 2.15899,
    'params': ','.join(['airTemperature']),
    'start': '2022-07-01 01:00:00',  
    'end': '2022-08-02 08:00:00'  
  },
  headers={
    'Authorization': apiKey
  }
)

# %%
# Do something with response data.
json_data = response.json()



barcelona = pd.DataFrame([json_data])


barcelona= barcelona.join(json_normalize(barcelona['hours'].to_list()))

barcelona = barcelona.transpose()

barcelona = barcelona[2:]

barcelona = barcelona.join(json_normalize(barcelona[0].to_list()))\
                      .drop([0], axis=1)[['time', 'airTemperature.dwd']].rename(columns={'airTemperature.dwd':'temp'})

barcelona['city'] = 'Barcelona'

barcelona
# Out:
#                           time   temp       city
# 0    2022-07-01T01:00:00+00:00  17.64  Barcelona
# 1    2022-07-01T02:00:00+00:00  17.71  Barcelona
# 2    2022-07-01T03:00:00+00:00  17.85  Barcelona
# 3    2022-07-01T04:00:00+00:00  17.97  Barcelona
# 4    2022-07-01T05:00:00+00:00  18.22  Barcelona
# ..                         ...    ...        ...
# 235  2022-07-10T20:00:00+00:00  24.40  Barcelona
# 236  2022-07-10T21:00:00+00:00  22.75  Barcelona
# 237  2022-07-10T22:00:00+00:00  21.59  Barcelona
# 238  2022-07-10T23:00:00+00:00  21.16  Barcelona
# 239  2022-07-11T00:00:00+00:00  20.91  Barcelona
#
# [240 rows x 3 columns]

# %%
import requests
import json



#barcelona = 41.38879	2.15899
#budapest = 47.49835	19.04045
apiKey= 'ffca9f02-39a7-11ed-93b0-0242ac130002-ffca9f70-39a7-11ed-93b0-0242ac130002' 
response = requests.get(
  'https://api.stormglass.io/v2/weather/point',
  params={
    'lat': 47.4979,
    'lng': 19.0402,
    'params': ','.join(['airTemperature']),
    'start': '2022-07-01 01:00:00',  
    'end': '2022-08-02 08:00:00'  
  },
  headers={
    'Authorization': apiKey
  }
)

json_data = response.json()


json_data
# Out:
# {'hours': [{'airTemperature': {'noaa': 24.66, 'sg': 24.66},
#    'time': '2022-07-01T01:00:00+00:00'},
#   {'airTemperature': {'noaa': 24.26, 'sg': 24.26},
#    'time': '2022-07-01T02:00:00+00:00'},
#   {'airTemperature': {'noaa': 23.87, 'sg': 23.87},
#    'time': '2022-07-01T03:00:00+00:00'},
#   {'airTemperature': {'noaa': 25.15, 'sg': 25.15},
#    'time': '2022-07-01T04:00:00+00:00'},
#   {'airTemperature': {'noaa': 26.43, 'sg': 26.43},
#    'time': '2022-07-01T05:00:00+00:00'},
#   {'airTemperature': {'noaa': 27.71, 'sg': 27.71},
#    'time': '2022-07-01T06:00:00+00:00'},
#   {'airTemperature': {'noaa': 29.47, 'sg': 29.47},
#    'time': '2022-07-01T07:00:00+00:00'},
#   {'airTemperature': {'noaa': 31.24, 'sg': 31.24},
#    'time': '2022-07-01T08:00:00+00:00'},
#   {'airTemperature': {'noaa': 33.01, 'sg': 33.01},
#    'time': '2022-07-01T09:00:00+00:00'},
#   {'airTemperature': {'noaa': 34.09, 'sg': 34.09},
#    'time': '2022-07-01T10:00:00+00:00'},
#   {'airTemperature': {'noaa': 35.17, 'sg': 35.17},
#    'time': '2022-07-01T11:00:00+00:00'},
#   {'airTemperature': {'noaa': 36.25, 'sg': 36.25},
#    'time': '2022-07-01T12:00:00+00:00'},
#   {'airTemperature': {'noaa': 36.5, 'sg': 36.5},
#    'time': '2022-07-01T13:00:00+00:00'},
#   {'airTemperature': {'noaa': 36.74, 'sg': 36.74},
#    'time': '2022-07-01T14:00:00+00:00'},
#   {'airTemperature': {'noaa': 36.99, 'sg': 36.99},
#    'time': '2022-07-01T15:00:00+00:00'},
#   {'airTemperature': {'noaa': 35.09, 'sg': 35.09},
#    'time': '2022-07-01T16:00:00+00:00'},
#   {'airTemperature': {'noaa': 33.19, 'sg': 33.19},
#    'time': '2022-07-01T17:00:00+00:00'},
#   {'airTemperature': {'noaa': 31.29, 'sg': 31.29},
#    'time': '2022-07-01T18:00:00+00:00'},
#   {'airTemperature': {'noaa': 27.43, 'sg': 27.43},
#    'time': '2022-07-01T19:00:00+00:00'},
#   {'airTemperature': {'noaa': 23.57, 'sg': 23.57},
#    'time': '2022-07-01T20:00:00+00:00'},
#   {'airTemperature': {'noaa': 19.71, 'sg': 19.71},
#    'time': '2022-07-01T21:00:00+00:00'},
#   {'airTemperature': {'noaa': 19.97, 'sg': 19.97},
#    'time': '2022-07-01T22:00:00+00:00'},
#   {'airTemperature': {'noaa': 20.23, 'sg': 20.23},
#    'time': '2022-07-01T23:00:00+00:00'},
#   {'airTemperature': {'noaa': 20.49, 'sg': 20.49},
#    'time': '2022-07-02T00:00:00+00:00'},
#   {'airTemperature': {'noaa': 19.73, 'sg': 19.73},
#    'time': '2022-07-02T01:00:00+00:00'},
#   {'airTemperature': {'noaa': 18.96, 'sg': 18.96},
#    'time': '2022-07-02T02:00:00+00:00'},
#   {'airTemperature': {'noaa': 18.2, 'sg': 18.2},
#    'time': '2022-07-02T03:00:00+00:00'},
#   {'airTemperature': {'noaa': 18.87, 'sg': 18.87},
#    'time': '2022-07-02T04:00:00+00:00'},
#   {'airTemperature': {'noaa': 19.54, 'sg': 19.54},
#    'time': '2022-07-02T05:00:00+00:00'},
#   {'airTemperature': {'noaa': 20.21, 'sg': 20.21},
#    'time': '2022-07-02T06:00:00+00:00'},
#   {'airTemperature': {'noaa': 22.23, 'sg': 22.23},
#    'time': '2022-07-02T07:00:00+00:00'},
#   {'airTemperature': {'noaa': 24.25, 'sg': 24.25},
#    'time': '2022-07-02T08:00:00+00:00'},
#   {'airTemperature': {'noaa': 26.27, 'sg': 26.27},
#    'time': '2022-07-02T09:00:00+00:00'},
#   {'airTemperature': {'noaa': 27.51, 'sg': 27.51},
#    'time': '2022-07-02T10:00:00+00:00'},
#   {'airTemperature': {'noaa': 28.75, 'sg': 28.75},
#    'time': '2022-07-02T11:00:00+00:00'},
#   {'airTemperature': {'noaa': 29.99, 'sg': 29.99},
#    'time': '2022-07-02T12:00:00+00:00'},
#   {'airTemperature': {'noaa': 30.11, 'sg': 30.11},
#    'time': '2022-07-02T13:00:00+00:00'},
#   {'airTemperature': {'noaa': 30.22, 'sg': 30.22},
#    'time': '2022-07-02T14:00:00+00:00'},
#   {'airTemperature': {'noaa': 30.34, 'sg': 30.34},
#    'time': '2022-07-02T15:00:00+00:00'},
#   {'airTemperature': {'noaa': 29.33, 'sg': 29.33},
#    'time': '2022-07-02T16:00:00+00:00'},
#   {'airTemperature': {'noaa': 28.31, 'sg': 28.31},
#    'time': '2022-07-02T17:00:00+00:00'},
#   {'airTemperature': {'noaa': 27.29, 'sg': 27.29},
#    'time': '2022-07-02T18:00:00+00:00'},
#   {'airTemperature': {'noaa': 26.11, 'sg': 26.11},
#    'time': '2022-07-02T19:00:00+00:00'},
#   {'airTemperature': {'noaa': 24.93, 'sg': 24.93},
#    'time': '2022-07-02T20:00:00+00:00'},
#   {'airTemperature': {'noaa': 23.75, 'sg': 23.75},
#    'time': '2022-07-02T21:00:00+00:00'},
#   {'airTemperature': {'noaa': 23.04, 'sg': 23.04},
#    'time': '2022-07-02T22:00:00+00:00'},
#   {'airTemperature': {'noaa': 22.33, 'sg': 22.33},
#    'time': '2022-07-02T23:00:00+00:00'},
#   {'airTemperature': {'noaa': 21.62, 'sg': 21.62},
#    'time': '2022-07-03T00:00:00+00:00'},
#   {'airTemperature': {'noaa': 21.28, 'sg': 21.28},
#    'time': '2022-07-03T01:00:00+00:00'},
#   {'airTemperature': {'noaa': 20.94, 'sg': 20.94},
#    'time': '2022-07-03T02:00:00+00:00'},
#   {'airTemperature': {'noaa': 20.6, 'sg': 20.6},
#    'time': '2022-07-03T03:00:00+00:00'},
#   {'airTemperature': {'noaa': 21.53, 'sg': 21.53},
#    'time': '2022-07-03T04:00:00+00:00'},
#   {'airTemperature': {'noaa': 22.46, 'sg': 22.46},
#    'time': '2022-07-03T05:00:00+00:00'},
#   {'airTemperature': {'noaa': 23.39, 'sg': 23.39},
#    'time': '2022-07-03T06:00:00+00:00'},
#   {'airTemperature': {'noaa': 25.19, 'sg': 25.19},
#    'time': '2022-07-03T07:00:00+00:00'},
#   {'airTemperature': {'noaa': 27.0, 'sg': 27.0},
#    'time': '2022-07-03T08:00:00+00:00'},
#   {'airTemperature': {'noaa': 28.8, 'sg': 28.8},
#    'time': '2022-07-03T09:00:00+00:00'},
#   {'airTemperature': {'noaa': 29.97, 'sg': 29.97},
#    'time': '2022-07-03T10:00:00+00:00'},
#   {'airTemperature': {'noaa': 31.13, 'sg': 31.13},
#    'time': '2022-07-03T11:00:00+00:00'},
#   {'airTemperature': {'noaa': 32.29, 'sg': 32.29},
#    'time': '2022-07-03T12:00:00+00:00'},
#   {'airTemperature': {'noaa': 32.5, 'sg': 32.5},
#    'time': '2022-07-03T13:00:00+00:00'},
#   {'airTemperature': {'noaa': 32.71, 'sg': 32.71},
#    'time': '2022-07-03T14:00:00+00:00'},
#   {'airTemperature': {'noaa': 32.93, 'sg': 32.93},
#    'time': '2022-07-03T15:00:00+00:00'},
#   {'airTemperature': {'noaa': 31.87, 'sg': 31.87},
#    'time': '2022-07-03T16:00:00+00:00'},
#   {'airTemperature': {'noaa': 30.82, 'sg': 30.82},
#    'time': '2022-07-03T17:00:00+00:00'},
#   {'airTemperature': {'noaa': 29.77, 'sg': 29.77},
#    'time': '2022-07-03T18:00:00+00:00'},
#   {'airTemperature': {'noaa': 28.42, 'sg': 28.42},
#    'time': '2022-07-03T19:00:00+00:00'},
#   {'airTemperature': {'noaa': 27.07, 'sg': 27.07},
#    'time': '2022-07-03T20:00:00+00:00'},
#   {'airTemperature': {'noaa': 25.72, 'sg': 25.72},
#    'time': '2022-07-03T21:00:00+00:00'},
#   {'airTemperature': {'noaa': 24.9, 'sg': 24.9},
#    'time': '2022-07-03T22:00:00+00:00'},
#   {'airTemperature': {'noaa': 24.07, 'sg': 24.07},
#    'time': '2022-07-03T23:00:00+00:00'},
#   {'airTemperature': {'noaa': 23.25, 'sg': 23.25},
#    'time': '2022-07-04T00:00:00+00:00'},
#   {'airTemperature': {'noaa': 22.56, 'sg': 22.56},
#    'time': '2022-07-04T01:00:00+00:00'},
#   {'airTemperature': {'noaa': 21.88, 'sg': 21.88},
#    'time': '2022-07-04T02:00:00+00:00'},
#   {'airTemperature': {'noaa': 21.19, 'sg': 21.19},
#    'time': '2022-07-04T03:00:00+00:00'},
#   {'airTemperature': {'noaa': 22.75, 'sg': 22.75},
#    'time': '2022-07-04T04:00:00+00:00'},
#   {'airTemperature': {'noaa': 24.3, 'sg': 24.3},
#    'time': '2022-07-04T05:00:00+00:00'},
#   {'airTemperature': {'noaa': 25.85, 'sg': 25.85},
#    'time': '2022-07-04T06:00:00+00:00'},
#   {'airTemperature': {'noaa': 27.66, 'sg': 27.66},
#    'time': '2022-07-04T07:00:00+00:00'},
#   {'airTemperature': {'noaa': 29.46, 'sg': 29.46},
#    'time': '2022-07-04T08:00:00+00:00'},
#   {'airTemperature': {'noaa': 31.27, 'sg': 31.27},
#    'time': '2022-07-04T09:00:00+00:00'},
#   {'airTemperature': {'noaa': 32.47, 'sg': 32.47},
#    'time': '2022-07-04T10:00:00+00:00'},
#   {'airTemperature': {'noaa': 33.67, 'sg': 33.67},
#    'time': '2022-07-04T11:00:00+00:00'},
#   {'airTemperature': {'noaa': 34.87, 'sg': 34.87},
#    'time': '2022-07-04T12:00:00+00:00'},
#   {'airTemperature': {'noaa': 35.13, 'sg': 35.13},
#    'time': '2022-07-04T13:00:00+00:00'},
#   {'airTemperature': {'noaa': 35.39, 'sg': 35.39},
#    'time': '2022-07-04T14:00:00+00:00'},
#   {'airTemperature': {'noaa': 35.64, 'sg': 35.64},
#    'time': '2022-07-04T15:00:00+00:00'},
#   {'airTemperature': {'noaa': 34.52, 'sg': 34.52},
#    'time': '2022-07-04T16:00:00+00:00'},
#   {'airTemperature': {'noaa': 33.39, 'sg': 33.39},
#    'time': '2022-07-04T17:00:00+00:00'},
#   {'airTemperature': {'noaa': 32.26, 'sg': 32.26},
#    'time': '2022-07-04T18:00:00+00:00'},
#   {'airTemperature': {'noaa': 30.09, 'sg': 30.09},
#    'time': '2022-07-04T19:00:00+00:00'},
#   {'airTemperature': {'noaa': 27.92, 'sg': 27.92},
#    'time': '2022-07-04T20:00:00+00:00'},
#   {'airTemperature': {'noaa': 25.75, 'sg': 25.75},
#    'time': '2022-07-04T21:00:00+00:00'},
#   {'airTemperature': {'noaa': 24.86, 'sg': 24.86},
#    'time': '2022-07-04T22:00:00+00:00'},
#   {'airTemperature': {'noaa': 23.96, 'sg': 23.96},
#    'time': '2022-07-04T23:00:00+00:00'},
#   {'airTemperature': {'noaa': 23.06, 'sg': 23.06},
#    'time': '2022-07-05T00:00:00+00:00'},
#   {'airTemperature': {'noaa': 22.3, 'sg': 22.3},
#    'time': '2022-07-05T01:00:00+00:00'},
#   {'airTemperature': {'noaa': 21.54, 'sg': 21.54},
#    'time': '2022-07-05T02:00:00+00:00'},
#   {'airTemperature': {'noaa': 20.78, 'sg': 20.78},
#    'time': '2022-07-05T03:00:00+00:00'},
#   {'airTemperature': {'noaa': 21.02, 'sg': 21.02},
#    'time': '2022-07-05T04:00:00+00:00'},
#   {'airTemperature': {'noaa': 21.27, 'sg': 21.27},
#    'time': '2022-07-05T05:00:00+00:00'},
#   {'airTemperature': {'noaa': 21.51, 'sg': 21.51},
#    'time': '2022-07-05T06:00:00+00:00'},
#   {'airTemperature': {'noaa': 23.44, 'sg': 23.44},
#    'time': '2022-07-05T07:00:00+00:00'},
#   {'airTemperature': {'noaa': 25.36, 'sg': 25.36},
#    'time': '2022-07-05T08:00:00+00:00'},
#   {'airTemperature': {'noaa': 27.28, 'sg': 27.28},
#    'time': '2022-07-05T09:00:00+00:00'},
#   {'airTemperature': {'noaa': 27.77, 'sg': 27.77},
#    'time': '2022-07-05T10:00:00+00:00'},
#   {'airTemperature': {'noaa': 28.26, 'sg': 28.26},
#    'time': '2022-07-05T11:00:00+00:00'},
#   {'airTemperature': {'noaa': 28.75, 'sg': 28.75},
#    'time': '2022-07-05T12:00:00+00:00'},
#   {'airTemperature': {'noaa': 29.08, 'sg': 29.08},
#    'time': '2022-07-05T13:00:00+00:00'},
#   {'airTemperature': {'noaa': 29.42, 'sg': 29.42},
#    'time': '2022-07-05T14:00:00+00:00'},
#   {'airTemperature': {'noaa': 29.75, 'sg': 29.75},
#    'time': '2022-07-05T15:00:00+00:00'},
#   {'airTemperature': {'noaa': 27.13, 'sg': 27.13},
#    'time': '2022-07-05T16:00:00+00:00'},
#   {'airTemperature': {'noaa': 24.51, 'sg': 24.51},
#    'time': '2022-07-05T17:00:00+00:00'},
#   {'airTemperature': {'noaa': 21.89, 'sg': 21.89},
#    'time': '2022-07-05T18:00:00+00:00'},
#   {'airTemperature': {'noaa': 20.99, 'sg': 20.99},
#    'time': '2022-07-05T19:00:00+00:00'},
#   {'airTemperature': {'noaa': 20.09, 'sg': 20.09},
#    'time': '2022-07-05T20:00:00+00:00'},
#   {'airTemperature': {'noaa': 19.19, 'sg': 19.19},
#    'time': '2022-07-05T21:00:00+00:00'},
#   {'airTemperature': {'noaa': 19.15, 'sg': 19.15},
#    'time': '2022-07-05T22:00:00+00:00'},
#   {'airTemperature': {'noaa': 19.1, 'sg': 19.1},
#    'time': '2022-07-05T23:00:00+00:00'},
#   {'airTemperature': {'noaa': 19.06, 'sg': 19.06},
#    'time': '2022-07-06T00:00:00+00:00'},
#   {'airTemperature': {'noaa': 18.8, 'sg': 18.8},
#    'time': '2022-07-06T01:00:00+00:00'},
#   {'airTemperature': {'noaa': 18.55, 'sg': 18.55},
#    'time': '2022-07-06T02:00:00+00:00'},
#   {'airTemperature': {'noaa': 18.29, 'sg': 18.29},
#    'time': '2022-07-06T03:00:00+00:00'},
#   {'airTemperature': {'noaa': 19.41, 'sg': 19.41},
#    'time': '2022-07-06T04:00:00+00:00'},
#   {'airTemperature': {'noaa': 20.52, 'sg': 20.52},
#    'time': '2022-07-06T05:00:00+00:00'},
#   {'airTemperature': {'noaa': 21.64, 'sg': 21.64},
#    'time': '2022-07-06T06:00:00+00:00'},
#   {'airTemperature': {'noaa': 23.29, 'sg': 23.29},
#    'time': '2022-07-06T07:00:00+00:00'},
#   {'airTemperature': {'noaa': 24.94, 'sg': 24.94},
#    'time': '2022-07-06T08:00:00+00:00'},
#   {'airTemperature': {'noaa': 26.59, 'sg': 26.59},
#    'time': '2022-07-06T09:00:00+00:00'},
#   {'airTemperature': {'noaa': 27.84, 'sg': 27.84},
#    'time': '2022-07-06T10:00:00+00:00'},
#   {'airTemperature': {'noaa': 29.09, 'sg': 29.09},
#    'time': '2022-07-06T11:00:00+00:00'},
#   {'airTemperature': {'noaa': 30.33, 'sg': 30.33},
#    'time': '2022-07-06T12:00:00+00:00'},
#   {'airTemperature': {'noaa': 30.34, 'sg': 30.34},
#    'time': '2022-07-06T13:00:00+00:00'},
#   {'airTemperature': {'noaa': 30.34, 'sg': 30.34},
#    'time': '2022-07-06T14:00:00+00:00'},
#   {'airTemperature': {'noaa': 30.35, 'sg': 30.35},
#    'time': '2022-07-06T15:00:00+00:00'},
#   {'airTemperature': {'noaa': 29.21, 'sg': 29.21},
#    'time': '2022-07-06T16:00:00+00:00'},
#   {'airTemperature': {'noaa': 28.08, 'sg': 28.08},
#    'time': '2022-07-06T17:00:00+00:00'},
#   {'airTemperature': {'noaa': 26.94, 'sg': 26.94},
#    'time': '2022-07-06T18:00:00+00:00'},
#   {'airTemperature': {'noaa': 25.76, 'sg': 25.76},
#    'time': '2022-07-06T19:00:00+00:00'},
#   {'airTemperature': {'noaa': 24.58, 'sg': 24.58},
#    'time': '2022-07-06T20:00:00+00:00'},
#   {'airTemperature': {'noaa': 23.4, 'sg': 23.4},
#    'time': '2022-07-06T21:00:00+00:00'},
#   {'airTemperature': {'noaa': 23.2, 'sg': 23.2},
#    'time': '2022-07-06T22:00:00+00:00'},
#   {'airTemperature': {'noaa': 22.99, 'sg': 22.99},
#    'time': '2022-07-06T23:00:00+00:00'},
#   {'airTemperature': {'noaa': 22.79, 'sg': 22.79},
#    'time': '2022-07-07T00:00:00+00:00'},
#   {'airTemperature': {'noaa': 22.08, 'sg': 22.08},
#    'time': '2022-07-07T01:00:00+00:00'},
#   {'airTemperature': {'noaa': 21.38, 'sg': 21.38},
#    'time': '2022-07-07T02:00:00+00:00'},
#   {'airTemperature': {'noaa': 20.68, 'sg': 20.68},
#    'time': '2022-07-07T03:00:00+00:00'},
#   {'airTemperature': {'noaa': 21.71, 'sg': 21.71},
#    'time': '2022-07-07T04:00:00+00:00'},
#   {'airTemperature': {'noaa': 22.74, 'sg': 22.74},
#    'time': '2022-07-07T05:00:00+00:00'},
#   {'airTemperature': {'noaa': 23.77, 'sg': 23.77},
#    'time': '2022-07-07T06:00:00+00:00'},
#   {'airTemperature': {'noaa': 24.98, 'sg': 24.98},
#    'time': '2022-07-07T07:00:00+00:00'},
#   {'airTemperature': {'noaa': 26.18, 'sg': 26.18},
#    'time': '2022-07-07T08:00:00+00:00'},
#   {'airTemperature': {'noaa': 27.39, 'sg': 27.39},
#    'time': '2022-07-07T09:00:00+00:00'},
#   {'airTemperature': {'noaa': 27.69, 'sg': 27.69},
#    'time': '2022-07-07T10:00:00+00:00'},
#   {'airTemperature': {'noaa': 27.99, 'sg': 27.99},
#    'time': '2022-07-07T11:00:00+00:00'},
#   {'airTemperature': {'noaa': 28.29, 'sg': 28.29},
#    'time': '2022-07-07T12:00:00+00:00'},
#   {'airTemperature': {'noaa': 28.01, 'sg': 28.01},
#    'time': '2022-07-07T13:00:00+00:00'},
#   {'airTemperature': {'noaa': 27.74, 'sg': 27.74},
#    'time': '2022-07-07T14:00:00+00:00'},
#   {'airTemperature': {'noaa': 27.46, 'sg': 27.46},
#    'time': '2022-07-07T15:00:00+00:00'},
#   {'airTemperature': {'noaa': 26.42, 'sg': 26.42},
#    'time': '2022-07-07T16:00:00+00:00'},
#   {'airTemperature': {'noaa': 25.38, 'sg': 25.38},
#    'time': '2022-07-07T17:00:00+00:00'},
#   {'airTemperature': {'noaa': 24.34, 'sg': 24.34},
#    'time': '2022-07-07T18:00:00+00:00'},
#   {'airTemperature': {'noaa': 22.96, 'sg': 22.96},
#    'time': '2022-07-07T19:00:00+00:00'},
#   {'airTemperature': {'noaa': 21.58, 'sg': 21.58},
#    'time': '2022-07-07T20:00:00+00:00'},
#   {'airTemperature': {'noaa': 20.21, 'sg': 20.21},
#    'time': '2022-07-07T21:00:00+00:00'},
#   {'airTemperature': {'noaa': 19.56, 'sg': 19.56},
#    'time': '2022-07-07T22:00:00+00:00'},
#   {'airTemperature': {'noaa': 18.92, 'sg': 18.92},
#    'time': '2022-07-07T23:00:00+00:00'},
#   {'airTemperature': {'noaa': 18.28, 'sg': 18.28},
#    'time': '2022-07-08T00:00:00+00:00'},
#   {'airTemperature': {'noaa': 17.55, 'sg': 17.55},
#    'time': '2022-07-08T01:00:00+00:00'},
#   {'airTemperature': {'noaa': 16.82, 'sg': 16.82},
#    'time': '2022-07-08T02:00:00+00:00'},
#   {'airTemperature': {'noaa': 16.09, 'sg': 16.09},
#    'time': '2022-07-08T03:00:00+00:00'},
#   {'airTemperature': {'noaa': 16.81, 'sg': 16.81},
#    'time': '2022-07-08T04:00:00+00:00'},
#   {'airTemperature': {'noaa': 17.53, 'sg': 17.53},
#    'time': '2022-07-08T05:00:00+00:00'},
#   {'airTemperature': {'noaa': 18.25, 'sg': 18.25},
#    'time': '2022-07-08T06:00:00+00:00'},
#   {'airTemperature': {'noaa': 19.27, 'sg': 19.27},
#    'time': '2022-07-08T07:00:00+00:00'},
#   {'airTemperature': {'noaa': 20.29, 'sg': 20.29},
#    'time': '2022-07-08T08:00:00+00:00'},
#   {'airTemperature': {'noaa': 21.31, 'sg': 21.31},
#    'time': '2022-07-08T09:00:00+00:00'},
#   {'airTemperature': {'noaa': 22.65, 'sg': 22.65},
#    'time': '2022-07-08T10:00:00+00:00'},
#   {'airTemperature': {'noaa': 24.0, 'sg': 24.0},
#    'time': '2022-07-08T11:00:00+00:00'},
#   {'airTemperature': {'noaa': 25.34, 'sg': 25.34},
#    'time': '2022-07-08T12:00:00+00:00'},
#   {'airTemperature': {'noaa': 24.58, 'sg': 24.58},
#    'time': '2022-07-08T13:00:00+00:00'},
#   {'airTemperature': {'noaa': 23.82, 'sg': 23.82},
#    'time': '2022-07-08T14:00:00+00:00'},
#   {'airTemperature': {'noaa': 23.06, 'sg': 23.06},
#    'time': '2022-07-08T15:00:00+00:00'},
#   {'airTemperature': {'noaa': 22.35, 'sg': 22.35},
#    'time': '2022-07-08T16:00:00+00:00'},
#   {'airTemperature': {'noaa': 21.64, 'sg': 21.64},
#    'time': '2022-07-08T17:00:00+00:00'},
#   {'airTemperature': {'noaa': 20.94, 'sg': 20.94},
#    'time': '2022-07-08T18:00:00+00:00'},
#   {'airTemperature': {'noaa': 19.85, 'sg': 19.85},
#    'time': '2022-07-08T19:00:00+00:00'},
#   {'airTemperature': {'noaa': 18.77, 'sg': 18.77},
#    'time': '2022-07-08T20:00:00+00:00'},
#   {'airTemperature': {'noaa': 17.69, 'sg': 17.69},
#    'time': '2022-07-08T21:00:00+00:00'},
#   {'airTemperature': {'noaa': 17.68, 'sg': 17.68},
#    'time': '2022-07-08T22:00:00+00:00'},
#   {'airTemperature': {'noaa': 17.67, 'sg': 17.67},
#    'time': '2022-07-08T23:00:00+00:00'},
#   {'airTemperature': {'noaa': 17.65, 'sg': 17.65},
#    'time': '2022-07-09T00:00:00+00:00'},
#   {'airTemperature': {'noaa': 16.72, 'sg': 16.72},
#    'time': '2022-07-09T01:00:00+00:00'},
#   {'airTemperature': {'noaa': 15.78, 'sg': 15.78},
#    'time': '2022-07-09T02:00:00+00:00'},
#   {'airTemperature': {'noaa': 14.85, 'sg': 14.85},
#    'time': '2022-07-09T03:00:00+00:00'},
#   {'airTemperature': {'noaa': 16.18, 'sg': 16.18},
#    'time': '2022-07-09T04:00:00+00:00'},
#   {'airTemperature': {'noaa': 17.52, 'sg': 17.52},
#    'time': '2022-07-09T05:00:00+00:00'},
#   {'airTemperature': {'noaa': 18.85, 'sg': 18.85},
#    'time': '2022-07-09T06:00:00+00:00'},
#   {'airTemperature': {'noaa': 20.62, 'sg': 20.62},
#    'time': '2022-07-09T07:00:00+00:00'},
#   {'airTemperature': {'noaa': 22.39, 'sg': 22.39},
#    'time': '2022-07-09T08:00:00+00:00'},
#   {'airTemperature': {'noaa': 24.16, 'sg': 24.16},
#    'time': '2022-07-09T09:00:00+00:00'},
#   {'airTemperature': {'noaa': 24.42, 'sg': 24.42},
#    'time': '2022-07-09T10:00:00+00:00'},
#   {'airTemperature': {'noaa': 24.68, 'sg': 24.68},
#    'time': '2022-07-09T11:00:00+00:00'},
#   {'airTemperature': {'noaa': 24.95, 'sg': 24.95},
#    'time': '2022-07-09T12:00:00+00:00'},
#   {'airTemperature': {'noaa': 24.49, 'sg': 24.49},
#    'time': '2022-07-09T13:00:00+00:00'},
#   {'airTemperature': {'noaa': 24.03, 'sg': 24.03},
#    'time': '2022-07-09T14:00:00+00:00'},
#   {'airTemperature': {'noaa': 23.58, 'sg': 23.58},
#    'time': '2022-07-09T15:00:00+00:00'},
#   {'airTemperature': {'noaa': 22.87, 'sg': 22.87},
#    'time': '2022-07-09T16:00:00+00:00'},
#   {'airTemperature': {'noaa': 22.16, 'sg': 22.16},
#    'time': '2022-07-09T17:00:00+00:00'},
#   {'airTemperature': {'noaa': 21.45, 'sg': 21.45},
#    'time': '2022-07-09T18:00:00+00:00'},
#   {'airTemperature': {'noaa': 20.1, 'sg': 20.1},
#    'time': '2022-07-09T19:00:00+00:00'},
#   {'airTemperature': {'noaa': 18.76, 'sg': 18.76},
#    'time': '2022-07-09T20:00:00+00:00'},
#   {'airTemperature': {'noaa': 17.42, 'sg': 17.42},
#    'time': '2022-07-09T21:00:00+00:00'},
#   {'airTemperature': {'noaa': 16.59, 'sg': 16.59},
#    'time': '2022-07-09T22:00:00+00:00'},
#   {'airTemperature': {'noaa': 15.77, 'sg': 15.77},
#    'time': '2022-07-09T23:00:00+00:00'},
#   {'airTemperature': {'noaa': 14.95, 'sg': 14.95},
#    'time': '2022-07-10T00:00:00+00:00'},
#   {'airTemperature': {'noaa': 14.7, 'sg': 14.7},
#    'time': '2022-07-10T01:00:00+00:00'},
#   {'airTemperature': {'noaa': 14.45, 'sg': 14.45},
#    'time': '2022-07-10T02:00:00+00:00'},
#   {'airTemperature': {'noaa': 14.19, 'sg': 14.19},
#    'time': '2022-07-10T03:00:00+00:00'},
#   {'airTemperature': {'noaa': 15.12, 'sg': 15.12},
#    'time': '2022-07-10T04:00:00+00:00'},
#   {'airTemperature': {'noaa': 16.05, 'sg': 16.05},
#    'time': '2022-07-10T05:00:00+00:00'},
#   {'airTemperature': {'noaa': 16.98, 'sg': 16.98},
#    'time': '2022-07-10T06:00:00+00:00'},
#   {'airTemperature': {'noaa': 18.77, 'sg': 18.77},
#    'time': '2022-07-10T07:00:00+00:00'},
#   {'airTemperature': {'noaa': 20.57, 'sg': 20.57},
#    'time': '2022-07-10T08:00:00+00:00'},
#   {'airTemperature': {'noaa': 22.36, 'sg': 22.36},
#    'time': '2022-07-10T09:00:00+00:00'},
#   {'airTemperature': {'noaa': 23.0, 'sg': 23.0},
#    'time': '2022-07-10T10:00:00+00:00'},
#   {'airTemperature': {'noaa': 23.64, 'sg': 23.64},
#    'time': '2022-07-10T11:00:00+00:00'},
#   {'airTemperature': {'noaa': 24.27, 'sg': 24.27},
#    'time': '2022-07-10T12:00:00+00:00'},
#   {'airTemperature': {'noaa': 23.59, 'sg': 23.59},
#    'time': '2022-07-10T13:00:00+00:00'},
#   {'airTemperature': {'noaa': 22.91, 'sg': 22.91},
#    'time': '2022-07-10T14:00:00+00:00'},
#   {'airTemperature': {'noaa': 22.23, 'sg': 22.23},
#    'time': '2022-07-10T15:00:00+00:00'},
#   {'airTemperature': {'noaa': 22.17, 'sg': 22.17},
#    'time': '2022-07-10T16:00:00+00:00'},
#   {'airTemperature': {'noaa': 22.12, 'sg': 22.12},
#    'time': '2022-07-10T17:00:00+00:00'},
#   {'airTemperature': {'noaa': 22.07, 'sg': 22.07},
#    'time': '2022-07-10T18:00:00+00:00'},
#   {'airTemperature': {'noaa': 20.78, 'sg': 20.78},
#    'time': '2022-07-10T19:00:00+00:00'},
#   {'airTemperature': {'noaa': 19.49, 'sg': 19.49},
#    'time': '2022-07-10T20:00:00+00:00'},
#   {'airTemperature': {'noaa': 18.2, 'sg': 18.2},
#    'time': '2022-07-10T21:00:00+00:00'},
#   {'airTemperature': {'noaa': 17.6, 'sg': 17.6},
#    'time': '2022-07-10T22:00:00+00:00'},
#   {'airTemperature': {'noaa': 17.01, 'sg': 17.01},
#    'time': '2022-07-10T23:00:00+00:00'},
#   {'airTemperature': {'noaa': 16.42, 'sg': 16.42},
#    'time': '2022-07-11T00:00:00+00:00'}],
#  'meta': {'cost': 1,
#   'dailyQuota': 10,
#   'end': '2022-07-11 00:00',
#   'lat': 47.4979,
#   'lng': 19.0402,
#   'params': ['airTemperature'],
#   'requestCount': 11,
#   'start': '2022-07-01 01:00'}}

# %%
budapest = pd.DataFrame([json_data])


budapest= budapest.join(json_normalize(budapest['hours'].to_list()))

budapest = budapest.transpose()

budapest = budapest[2:]

budapest = budapest.join(json_normalize(budapest[0].to_list()))\
                      .drop([0], axis=1)[['time', 'airTemperature.noaa']].rename(columns={'airTemperature.noaa':'temp'})

budapest['city'] = 'Budapest'




budapest
# Out:
#                           time   temp      city
# 0    2022-07-01T01:00:00+00:00  24.66  Budapest
# 1    2022-07-01T02:00:00+00:00  24.26  Budapest
# 2    2022-07-01T03:00:00+00:00  23.87  Budapest
# 3    2022-07-01T04:00:00+00:00  25.15  Budapest
# 4    2022-07-01T05:00:00+00:00  26.43  Budapest
# ..                         ...    ...       ...
# 235  2022-07-10T20:00:00+00:00  19.49  Budapest
# 236  2022-07-10T21:00:00+00:00  18.20  Budapest
# 237  2022-07-10T22:00:00+00:00  17.60  Budapest
# 238  2022-07-10T23:00:00+00:00  17.01  Budapest
# 239  2022-07-11T00:00:00+00:00  16.42  Budapest
#
# [240 rows x 3 columns]

# %%
apiTemperature = pd.concat([barcelona,budapest])

apiTemperature.to_parquet('C:/Users/E.ALVAREZHERNANDEZ/VS Projects/caseStudy/clean_data/DataLake/apiWeather.parquet',compression='snappy')

# %%
apiweather = pd.read_parquet('C:/Users/E.ALVAREZHERNANDEZ/VS Projects/caseStudy/clean_data/DataLake/apiWeather.parquet')

apiweather['time'] = pd.to_datetime(apiweather['time']).apply(lambda x: datetime.datetime.strftime(x, '%Y-%m-%d %H:%M:%S'))

apiweather
# Out:
#                     time   temp       city
# 0    2022-07-01 01:00:00  17.64  Barcelona
# 1    2022-07-01 02:00:00  17.71  Barcelona
# 2    2022-07-01 03:00:00  17.85  Barcelona
# 3    2022-07-01 04:00:00  17.97  Barcelona
# 4    2022-07-01 05:00:00  18.22  Barcelona
# ..                   ...    ...        ...
# 235  2022-07-10 20:00:00  19.49   Budapest
# 236  2022-07-10 21:00:00  18.20   Budapest
# 237  2022-07-10 22:00:00  17.60   Budapest
# 238  2022-07-10 23:00:00  17.01   Budapest
# 239  2022-07-11 00:00:00  16.42   Budapest
#
# [480 rows x 3 columns]

# %%
newshdf = shdf[(shdf['start_location']=='Barcelona')&(shdf['end_location']=='Budapest') ]
newshdf
# Out:
#         id  truck  driver shipment_start_timestamp shipment_end_timestamp  \
# 1666  9932   4587    2749      2022-07-04 12:00:00    2022-07-05 12:00:00
# 1667  9253   9408    5519      2022-07-02 12:00:00    2022-07-03 13:00:00
# 1668  9213   1036    6421      2022-07-04 10:00:00    2022-07-05 10:00:00
# 1669  9144   4119    6731      2022-07-24 17:00:00    2022-07-25 19:00:00
# 1670  8637   1912    8778      2022-07-12 19:00:00    2022-07-13 20:00:00
# 1671  8426   3900    2238      2022-07-15 18:00:00    2022-07-16 17:00:00
# 1672  8210   4137    3095      2022-07-01 23:00:00    2022-07-03 00:00:00
# 1673  6649   2239    3261      2022-07-04 03:00:00    2022-07-05 06:00:00
# 1674  6357   9736    3223      2022-07-02 08:00:00    2022-07-03 11:00:00
# 1675  5889   7224    8588      2022-07-28 22:00:00    2022-07-29 22:00:00
# 1676  5838   6005    1167      2022-07-21 20:00:00    2022-07-22 19:00:00
# 1677  5594   5454    8468      2022-07-18 02:00:00    2022-07-19 02:00:00
# 1678  5582   2735    4869      2022-07-05 03:00:00    2022-07-06 03:00:00
# 1679  5520   9776    8003      2022-07-23 08:00:00    2022-07-24 10:00:00
# 1680  4992   8800    7752      2022-07-01 09:00:00    2022-07-02 08:00:00
# 1681  4756   8583    6106      2022-07-28 13:00:00    2022-07-29 16:00:00
# 1682  4353   5114    8447      2022-07-24 04:00:00    2022-07-25 04:00:00
# 1683  3774   4945    8004      2022-07-30 17:00:00    2022-07-31 20:00:00
# 1684  3670   4885    8182      2022-07-08 04:00:00    2022-07-09 03:00:00
# 1685  3489   1521    5550      2022-07-11 13:00:00    2022-07-12 16:00:00
# 1686  2490   9393    1648      2022-07-22 22:00:00    2022-07-23 21:00:00
# 1687  1315   9485    5485      2022-07-26 03:00:00    2022-07-27 06:00:00
# 1688   565   2215    3266      2022-07-13 08:00:00    2022-07-14 10:00:00
# 1689   530   9107    3715      2022-07-16 18:00:00    2022-07-17 18:00:00
#
#      start_location end_location  shipment_distance  consumed_fuel  \
# 1666      Barcelona     Budapest           1799.821         249.90
# 1667      Barcelona     Budapest           1799.821         260.91
# 1668      Barcelona     Budapest           1799.821         253.04
# 1669      Barcelona     Budapest           1799.821         275.44
# 1670      Barcelona     Budapest           1799.821         268.84
# 1671      Barcelona     Budapest           1799.821         263.21
# 1672      Barcelona     Budapest           1799.821         255.85
# 1673      Barcelona     Budapest           1799.821         269.68
# 1674      Barcelona     Budapest           1799.821         268.41
# 1675      Barcelona     Budapest           1799.821         249.64
# 1676      Barcelona     Budapest           1799.821         272.01
# 1677      Barcelona     Budapest           1799.821         274.15
# 1678      Barcelona     Budapest           1799.821         274.09
# 1679      Barcelona     Budapest           1799.821         273.82
# 1680      Barcelona     Budapest           1799.821         269.74
# 1681      Barcelona     Budapest           1799.821         272.08
# 1682      Barcelona     Budapest           1799.821         258.51
# 1683      Barcelona     Budapest           1799.821         259.92
# 1684      Barcelona     Budapest           1799.821         254.16
# 1685      Barcelona     Budapest           1799.821         266.40
# 1686      Barcelona     Budapest           1799.821         272.12
# 1687      Barcelona     Budapest           1799.821         272.81
# 1688      Barcelona     Budapest           1799.821         268.63
# 1689      Barcelona     Budapest           1799.821         264.67
#
#       fConsumption
# 1666     13.884714
# 1667     14.496442
# 1668     14.059176
# 1669     15.303744
# 1670     14.937041
# 1671     14.624232
# 1672     14.215303
# 1673     14.983712
# 1674     14.913150
# 1675     13.870268
# 1676     15.113170
# 1677     15.232070
# 1678     15.228737
# 1679     15.213735
# 1680     14.987046
# 1681     15.117059
# 1682     14.363095
# 1683     14.441436
# 1684     14.121404
# 1685     14.801472
# 1686     15.119281
# 1687     15.157618
# 1688     14.925373
# 1689     14.705351

# %%
dfmerge3 = pd.merge(newshdf, apiweather, how='left', left_on=[newshdf['start_location'].astype(str), newshdf['shipment_start_timestamp'].astype(str)], right_on=[apiweather['city'].astype(str), apiweather['time'].astype(str)])
dfmerge3= dfmerge3.rename(columns={'temp':'startTemp'}).drop(['key_0', 'key_1', 'city', 'time'], axis=1)

dfmerge4 = pd.merge(dfmerge3, apiweather, how='left', left_on=[dfmerge3['end_location'].astype(str), dfmerge3['shipment_end_timestamp'].astype(str)], right_on=[apiweather['city'].astype(str), apiweather['time'].astype(str)])
dfmerge4= dfmerge4.drop(['key_0', 'key_1', 'time', 'city'], axis=1).rename(columns={'temp':'endTemp'})

dfmerge4 = dfmerge4.dropna(subset=['startTemp'])

dfmerge4
# Out:
#       id  truck  driver shipment_start_timestamp shipment_end_timestamp  \
# 0   9932   4587    2749      2022-07-04 12:00:00    2022-07-05 12:00:00
# 1   9253   9408    5519      2022-07-02 12:00:00    2022-07-03 13:00:00
# 2   9213   1036    6421      2022-07-04 10:00:00    2022-07-05 10:00:00
# 6   8210   4137    3095      2022-07-01 23:00:00    2022-07-03 00:00:00
# 7   6649   2239    3261      2022-07-04 03:00:00    2022-07-05 06:00:00
# 8   6357   9736    3223      2022-07-02 08:00:00    2022-07-03 11:00:00
# 12  5582   2735    4869      2022-07-05 03:00:00    2022-07-06 03:00:00
# 14  4992   8800    7752      2022-07-01 09:00:00    2022-07-02 08:00:00
# 18  3670   4885    8182      2022-07-08 04:00:00    2022-07-09 03:00:00
#
#    start_location end_location  shipment_distance  consumed_fuel  \
# 0       Barcelona     Budapest           1799.821         249.90
# 1       Barcelona     Budapest           1799.821         260.91
# 2       Barcelona     Budapest           1799.821         253.04
# 6       Barcelona     Budapest           1799.821         255.85
# 7       Barcelona     Budapest           1799.821         269.68
# 8       Barcelona     Budapest           1799.821         268.41
# 12      Barcelona     Budapest           1799.821         274.09
# 14      Barcelona     Budapest           1799.821         269.74
# 18      Barcelona     Budapest           1799.821         254.16
#
#     fConsumption  startTemp  endTemp
# 0      13.884714      30.40    28.75
# 1      14.496442      28.19    32.50
# 2      14.059176      31.98    27.77
# 6      14.215303      16.73    21.62
# 7      14.983712      19.32    21.51
# 8      14.913150      24.72    31.13
# 12     15.228737      19.95    18.29
# 14     14.987046      24.24    24.25
# 18     14.121404      18.44    14.85

# %%
dfmerge4.corr()
# Out:
#                          id     truck    driver  shipment_distance  \
# id                 1.000000 -0.131814 -0.518452                NaN
# truck             -0.131814  1.000000  0.109887                NaN
# driver            -0.518452  0.109887  1.000000                NaN
# shipment_distance       NaN       NaN       NaN                NaN
# consumed_fuel     -0.508053  0.231737 -0.028969                NaN
# fConsumption      -0.508053  0.231737 -0.028969                NaN
# startTemp          0.648869  0.125621  0.036081                NaN
# endTemp            0.698829  0.493346 -0.325019                NaN
#
#                    consumed_fuel  fConsumption  startTemp   endTemp
# id                     -0.508053     -0.508053   0.648869  0.698829
# truck                   0.231737      0.231737   0.125621  0.493346
# driver                 -0.028969     -0.028969   0.036081 -0.325019
# shipment_distance            NaN           NaN        NaN       NaN
# consumed_fuel           1.000000      1.000000  -0.366547 -0.125860
# fConsumption            1.000000      1.000000  -0.366547 -0.125860
# startTemp              -0.366547     -0.366547   1.000000  0.776972
# endTemp                -0.125860     -0.125860   0.776972  1.000000
